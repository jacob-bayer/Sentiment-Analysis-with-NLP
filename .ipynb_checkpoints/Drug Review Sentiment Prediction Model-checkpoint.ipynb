# %% [markdown]
# # Drug Review Sentiment Prediction Model
#
# #### By: Jacob Bayer

# %%
import pandas as pd
from nltk import word_tokenize
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from datetime import datetime
import time
import os

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn import metrics
from sklearn.naive_bayes import BernoulliNB

# %% [markdown]
# # Introduction
# This notebook demonstrates exploratory model building for a natural language processing dataset. This dataset consists of drug reviews from drugs.com, originally posted on the UCI Machine Learning Repository by Gräßer et al. (2018). The data presented here represent 10000 rows randomly selected from the approximately 215000 rows in the original data. These data exist in 6 dimensions, which represent the drug being reviewed, the condition that the drug is designed to treat, the review, the rating the user gave the drug, the date the review was given, and the number of users who found the review useful. Each review has a unique id.
#
# The explanations in this notebook assume basic familiarity with machine learning models and tecniques for evaluating their perforamnce.

# %% [markdown]
# ## Data loading

# %%
drug_reviews = pd.read_csv("https://raw.githubusercontent.com/jacob-bayer/project-datasets/main/drug_reviews.csv",
                           index_col = 0)

# %%
print("Dimensions \n", 
      "Rows:", drug_reviews.shape[0], "\n",
      "Columns:", drug_reviews.shape[1])
# Out:
# Dimensions
#  Rows: 10000
#  Columns: 6

# %%
display(drug_reviews.sample(10))
# Out:
#                                     drugName        condition  \
# uniqueID
# 175957                              Levaquin       Bronchitis
# 221434                      Dextromethorphan            Cough
# 52955                                 Maxalt         Migraine
# 57850            Acetaminophen / hydrocodone             Pain
# 196747                            Paroxetine          Anxiety
# 4018                             Seroquel XR  Bipolar Disorde
# 77147                             Lorcaserin      Weight Loss
# 212638                             Phenergan  Nausea/Vomiting
# 48778     Ethinyl estradiol / levonorgestrel    Birth Control
# 8719                                Zolpidem         Insomnia
#
#                                                      review  rating  \
# uniqueID
# 175957    "On my third day with Levaquin. Only problem t...       9
# 221434    "Took delsym cough about one hour ago. It has ...       5
# 52955     "This medicine is great it allows me to be abl...       9
# 57850     "I have Diabetes which caused my painful nerop...      10
# 196747    "Pros: works for anxiety, depression\r\n\r\nCo...       7
# 4018      "At first I hated this medication, made me rea...       8
# 77147       "Best medicine ever! Lost 30 lbs in one month!"      10
# 212638    "I tried this medicine a day after I vomited t...      10
# 48778     "If I missed my dosing time by an hour I spott...       2
# 8719      "I have taken Ambien, on and off, for several ...       7
#
#                date  usefulCount
# uniqueID
# 175957    24-Mar-09           33
# 221434    31-Dec-15            6
# 52955     14-May-08           14
# 57850      5-Jan-13           11
# 196747    26-Apr-17           24
# 4018       6-Apr-15           21
# 77147     19-Nov-14          180
# 212638    24-Sep-15           34
# 48778     15-Mar-17            0
# 8719      19-Jan-09           55

# %% [markdown]
# ## Data Cleaning
#
# #### Missing data

# %%
missing_rows = drug_reviews.isnull().any(axis=1)
drug_reviews[missing_rows].isna().sum()
# Out:
# drugName        0
# condition      59
# review          0
# rating          0
# date            0
# usefulCount     0
# dtype: int64

# %% [markdown]
# All cases of missing data in this dataset are missing conditions. These cases can be defined as conditions of their own in order to avoid them being grouped together under the same condition.

# %%
drug_reviews.loc[missing_rows, 'condition'] = drug_reviews.loc[missing_rows, 'drugName']

# %% [markdown]
# ##### Examples of Raw Reviews

# %%
drug_reviews['review'].iloc[65]
# Out:
# '"I took the Prepopik for my first colonoscopy (I&#039;m 25) and I found it to be very effective. The orange flavor was very tolerable. I had no bad cramps or terrible side effects with it, but I had taken magnesium citrate the night before and that had already cleaned me out somewhat. My only issue was I ended up so dehydrated that I showed up to my colonoscopy with a fever. Try to drink as much fluid as you can with this prep! I drank plenty, but there was more liquid coming out of me than going in. Overall, I would recommend the Prepopik. On a side note, my insurance didn&#039;t cover it, but the office I go to had it available. I recommend asking your office if they have it available if insurance won&#039;t cover it at the pharmacy."'

# %%
drug_reviews['review'].iloc[12]
# Out:
# '"I had Crohn&#039;s with a resection 30 years ago and have been mostly in remission since.  Have recently had a bad flare and narrowing at the anastomosis and need to be on medication, but haven&#039;t found one that I can handle.  Asacol gave me such serious body aching and fatigue that I could not function.  Pentasa immediately gave me heart palpitations and arrhythmias so I had to discontinue it."'

# %% [markdown]
# ### Text cleaning

# %% [markdown]
# #### Encoding/character Replacement
# The quotations around each review will be stripped, and the encodings for apostophes and ampersands will be replaced with the characters themselves.

# %%
def clean_review_encodings(review):
    replace_dict = {'"'      : '',
                    '&#039;' : "'",
                    '&amp'   : '&'}
    
    for key, value in replace_dict.items():
        review = review.replace(key, value)
        
    return review

# %%
drug_reviews['review'] = drug_reviews.review.map(clean_review_encodings)

# %% [markdown]
# #### Stemming
# Stemming changes every word from its inflected form to its stem (root) form so that different inflections of the same root are not counted as different words. For example, "walked" will become "walk", and "computers" will become "computer". Each word in every review will be stemmed after it has been converted to all lowercase characters.
#
# Punctuation and stop words ('not','a','the','it', etc) have been intentionally included. Since the reviews are so short, these words and symbols could hold significant meaning that they might not hold in a longer document.

# %%
# create stemmer object
lancaster = nltk.LancasterStemmer()

# list all drugnames
all_drugs = [drugname.lower() for drugname in drug_reviews['drugName']]

# create function to clean text
def clean_text(s):
    
    # convert text to lowercase
    s = s.lower()
    
    # tokenize each review
    tokens = nltk.tokenize.word_tokenize(s)
     
    # stem each token (walked --> walk, computers --> computer, etc.)
    # does not stem drug names
    clean_tokens = [lancaster.stem(token) 
                    if token not in all_drugs 
                    else token 
                    for token in tokens]
    
    return ' '.join(clean_tokens)

# %%
drug_reviews['cleaned_review'] = drug_reviews.review.map(clean_text)

# %% [markdown]
# #### Example of a short review:

# %% [markdown]
# Raw:

# %%
drug_reviews['review'].iloc[0]
# Out:
# 'It has no side effect, I take it in combination of Bystolic 5 Mg and Fish Oil'

# %% [markdown]
# Cleaned:

# %%
drug_reviews['cleaned_review'].iloc[0]
# Out:
# 'it has no sid effect , i tak it in combin of bystolic 5 mg and fish oil'

# %% [markdown]
# #### Example of a long review:

# %% [markdown]
# Raw:

# %%
drug_reviews['review'].iloc[50]
# Out:
# "Hey Guys,  It's been 4 months since my last post as I wanted to give it a few months to see how this was going to work.  So, I have been on Trulicity for six months now with Metformin.  When I hit the five month period the diarrhea, gas, sulphur belching finally subsided.  I now longer have any of those side effects.  However, I still haven't lost any weight at all, but I think that was because when I first started Trulicity I was taking it with Glimepiride and that one has a side effect of weight gain so I think the two meds were fighting each other lol.  I have been back on the Metformin with Trulicity for about a week now, so we will see what this does.  I was diagnosed as  stage 3 chronic kidney disease (CKD 3) so I am watching diet closely."

# %% [markdown]
# Cleaned:

# %%
drug_reviews['cleaned_review'].iloc[50]
# Out:
# "hey guy , it 's been 4 month sint my last post as i want to giv it a few month to see how thi was going to work . so , i hav been on trulicity for six month now with metformin . when i hit the fiv mon period the diarrhe , gas , sulph belch fin subsid . i now long hav any of thos sid effect . howev , i stil hav n't lost any weight at al , but i think that was becaus when i first start trulicity i was tak it with glimepiride and that on has a sid effect of weight gain so i think the two med wer fight each oth lol . i hav been back on the metformin with trulicity for about a week now , so we wil see what thi doe . i was diagnos as stag 3 chronic kidney diseas ( ckd 3 ) so i am watch diet clos ."

# %% [markdown]
# ### Defining the positive class
# The positive class in this dataset is any review with a rating over 5.
#
# (In the next section, different methods of feature generation from raw text data will be explored. For this reason, the independent variable (x) has been defined as simply the "cleaned review" at this stage.)

# %%
x = drug_reviews.cleaned_review
y = drug_reviews.rating.map(lambda x: 1 if x > 5 else 0)

# %% [markdown]
# ### Train-test sets
# To perform out-of-sample model evaluation, the model is trained on only 50% of the data and then used to make predictions on "new" data consisting of the remaining 50%.

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, 
                                                  train_size = 0.5, 
                                                  random_state = 0)

# %% [markdown]
# ## Generating Features

# %% [markdown]
# Features will be generated using several methods, and the feature set with the highest performance in a logistic regression model will be selected for further modelling.
#
# Methods covered:
# 1. Bag of words, or BOW (Harris, 1954)
# 2. Term frequency-inverse document frequency, or TF-IDF (Luhn, 1957; Spärck Jones, 1972)
# 3. Word2vec (Mikolov et al., 2013a, 2013b)

# %% [markdown]
# ### Bag of Words

# %% [markdown]
# Bag of words is a simplified representation of textual data used in natural language processing. This method focuses on the frequency distribution of each word type, but it does not respect grammar or word order.
#
# The frequencies of each unique word or ngram can be used as features to train the rating classifier.

# %%
count_vec = CountVectorizer(ngram_range = (1,1), stop_words = "english", lowercase = True)
train_counts = count_vec.fit_transform(x_train)

bag_train = pd.DataFrame(train_counts.toarray(), columns=count_vec.get_feature_names_out(), index = x_train.index)

# %% [markdown]
# #### The 30 most frequenty occuring words in the training data

# %%
word_counts = bag_train.sum()
word_counts = word_counts.sort_values(ascending = False)
word_counts.head(30)
# Out:
# hav       6161
# thi       3982
# tak       3268
# day       2994
# year      2063
# aft       2018
# work      1996
# effect    1940
# week      1864
# start     1834
# pain      1731
# sid       1640
# feel      1621
# tim       1572
# al        1538
# ve        1433
# did       1383
# month     1368
# med       1341
# lik       1325
# period    1294
# pil       1260
# just      1230
# ev        1135
# help      1080
# doct       998
# becaus     991
# mor        977
# got        972
# ar         961
# dtype: int64

# %% [markdown]
# #### Number of words in each observation

# %%
total_words = bag_train.sum(axis = 1)
total_words
# Out:
# uniqueID
# 57325     62
# 220496    45
# 123604    36
# 175572    73
# 193559    31
#           ..
# 179619    22
# 134481    16
# 219709    44
# 76401     54
# 148019    66
# Length: 5000, dtype: int64

# %% [markdown]
# #### The median number of words for a single observation is 39, based off below.

# %%
total_words.describe()
# Out:
# count    5000.000000
# mean       42.266600
# std        22.134704
# min         1.000000
# 25%        24.000000
# 50%        42.000000
# 75%        62.000000
# max       250.000000
# dtype: float64

# %%
def create_bow_features(x_train, x_val, ngram_range = (1,1), word_count_limit = 20):
    count_vec = CountVectorizer(ngram_range = ngram_range, lowercase = True)
    train_counts = count_vec.fit_transform(x_train)

    bag_train = pd.DataFrame(train_counts.toarray(), columns=count_vec.get_feature_names_out(), index = x_train.index)

    # Get a count of how often each word appears in the training data
    word_counts = bag_train.sum()
    word_counts = word_counts.sort_values(ascending = False)
    
    # Reduce the number of features down to words that occur at least n times
    reduced_bag_train = bag_train[word_counts[word_counts >= word_count_limit].index]
    
    # Standardize features
    reduced_bag_train = (reduced_bag_train - reduced_bag_train.mean()) / reduced_bag_train.std()
    
    # Get bag of words on validation set using the fit based off the training set
    val_counts = count_vec.transform(x_val)
    bag_val = pd.DataFrame(val_counts.toarray(), columns=count_vec.get_feature_names_out(), index = x_val.index)

    # Get reduced dataframe for validation dataset
    reduced_bag_val = bag_val[reduced_bag_train.columns]
    
    # Standardize features
    reduced_bag_val = (reduced_bag_val - reduced_bag_val.mean()) / reduced_bag_val.std()
    
    return reduced_bag_train, reduced_bag_val.fillna(0)

# %%
bow_train, bow_val = create_bow_features(x_train, x_val)

# %% [markdown]
# #### Example of bag of words data generated from raw text

# %%
bow_train.head()
# Out:
#                and       the        it        to        my        on  \
# uniqueID
# 57325    -0.331910  1.122135 -1.031821  1.673013 -0.460643 -0.949845
# 220496    0.620213 -0.220132  0.496501 -0.544514  1.817512 -0.949845
# 123604   -0.331910  0.227291  2.024822  1.118632  0.678434 -0.949845
# 175572    0.144151 -0.220132 -0.012940  0.009868  0.108896 -0.212731
# 193559    0.144151  0.227291 -0.012940  0.564250 -0.460643 -0.949845
#
#                for       hav       was        of  ...    whenev     traum  \
# uniqueID                                          ...
# 57325    -0.214431  0.562940 -0.079673  0.793905  ... -0.060406 -0.063366
# 220496   -1.031624  1.296125  0.607167 -0.035152  ... -0.060406 -0.063366
# 123604    1.419954 -0.903431 -0.079673 -0.864209  ... -0.060406 -0.063366
# 175572    1.419954 -0.170246 -0.079673 -0.035152  ... -0.060406 -0.063366
# 193559   -1.031624 -0.903431 -0.766514 -0.864209  ... -0.060406 -0.063366
#
#            aggress     boost     admit       par      abov   opposit  \
# uniqueID
# 57325    -0.063366 -0.057826 -0.063366 -0.060406 -0.063366 -0.063366
# 220496   -0.063366 -0.057826 -0.063366 -0.060406 -0.063366 -0.063366
# 123604   -0.063366 -0.057826 -0.063366 -0.060406 -0.063366 -0.063366
# 175572   -0.063366 -0.057826 -0.063366 -0.060406 -0.063366 -0.063366
# 193559   -0.063366 -0.057826 -0.063366 -0.060406 -0.063366 -0.063366
#
#            metabol     battl
# uniqueID
# 57325    -0.063366 -0.063366
# 220496   -0.063366 -0.063366
# 123604   -0.063366 -0.063366
# 175572   -0.063366 -0.063366
# 193559   -0.063366 -0.063366
#
# [5 rows x 1373 columns]

# %%
bow_val.head()
# Out:
#                and       the        it        to        my        on  \
# uniqueID
# 144223   -0.329169 -0.662671 -0.003009  1.612780  0.095120 -0.958629
# 63395     0.597025  0.671028  1.034708 -0.545074  2.367995 -0.222468
# 6524     -1.255364 -0.218104 -0.003009 -0.005610 -1.041318 -0.958629
# 68694     0.133928  0.671028 -0.521868 -0.545074  0.663339 -0.958629
# 6508      0.597025 -0.662671  0.515850 -0.005610 -0.473099  1.249855
#
#                for       hav       was        of  ...    whenev     traum  \
# uniqueID                                          ...
# 144223   -1.031955  1.324964  0.615208 -0.863744  ... -0.055234 -0.067973
# 63395    -1.031955 -0.153956  0.615208 -0.056356  ... -0.055234 -0.067973
# 6524      1.465113 -0.153956 -0.775093 -0.863744  ... -0.055234 -0.067973
# 68694    -0.199599 -0.893416 -0.775093 -0.863744  ... -0.055234 -0.067973
# 6508     -0.199599 -0.893416 -0.079942 -0.056356  ... -0.055234 -0.067973
#
#            aggress     boost     admit       par      abov   opposit  \
# uniqueID
# 144223   -0.060406 -0.046951 -0.080249 -0.054849 -0.070881 -0.058403
# 63395    -0.060406 -0.046951 -0.080249 -0.054849 -0.070881 -0.058403
# 6524     -0.060406 -0.046951 -0.080249 -0.054849 -0.070881 -0.058403
# 68694    -0.060406 -0.046951 -0.080249 -0.054849 -0.070881 -0.058403
# 6508     -0.060406 -0.046951 -0.080249 -0.054849 -0.070881 -0.058403
#
#            metabol     battl
# uniqueID
# 144223   -0.044762 -0.065185
# 63395    -0.044762 -0.065185
# 6524     -0.044762 -0.065185
# 68694    -0.044762 -0.065185
# 6508     -0.044762 -0.065185
#
# [5 rows x 1373 columns]

# %% [markdown]
# ### TF - IDF

# %% [markdown]
# TF-IDF stands for Term Frequency-Inverse Document Frequency. To create TF-IDF features from raw text, the Tfidfvectorizer function from SciKit will calculate a score for each token based on the relative importance of the token in a document vs the overall corpus. Compared with bag of words, TF-IDF not only considers the frequency of words on the document level but also considers the frequency of words on the corpus level.
#
# Words that occur less than 20 times are omitted. This can be changed by changing the word_count_limit.

# %%
def create_tf_idf_features(x_train, x_val, ngram_range = (1,1), word_count_limit = 20):
    
    ## tf_idf
    tf_idf = TfidfVectorizer(ngram_range = ngram_range, stop_words = "english", lowercase = True)

    # train
    train_tf_idf = tf_idf.fit_transform(x_train)
    train_tf_idf = pd.DataFrame(train_tf_idf.toarray(), columns = tf_idf.get_feature_names_out(), index = x_train.index)

    # validation
    val_tf_idf = tf_idf.transform(x_val)
    val_tf_idf = pd.DataFrame(val_tf_idf.toarray(), columns = tf_idf.get_feature_names_out(), index = x_val.index)
    
    # word counts
    word_counts = train_tf_idf.sum()
    word_counts = word_counts.sort_values(ascending = False)
    
    # get subset of columns based off word counts
    train_tf_idf = train_tf_idf[word_counts[word_counts >= word_count_limit].index]
    val_tf_idf = val_tf_idf[train_tf_idf.columns]
    
    # Standardize
    train_tf_idf = (train_tf_idf - train_tf_idf.mean()) / train_tf_idf.std()
    val_tf_idf = (val_tf_idf - val_tf_idf.mean()) / val_tf_idf.std()
    
    return train_tf_idf, val_tf_idf.fillna(0)

# %%
train_tf_idf, val_tf_idf = create_tf_idf_features(x_train, x_val)

# %% [markdown]
# #### Example of TF-IDF data generated from raw text

# %%
train_tf_idf.head()
# Out:
#                hav       thi       tak       day      work      pain  \
# uniqueID
# 57325     0.176254 -0.777215  2.496794  2.549079  1.174017  0.445719
# 220496    1.808628  1.527987 -0.708877 -0.616428 -0.517721 -0.413207
# 123604   -0.909089  1.459920 -0.708877  0.665644  0.852631  0.978298
# 175572   -0.356352 -0.073957  0.107406  1.801738  0.343838 -0.413207
# 193559   -0.909089 -0.777215 -0.708877  0.492185  0.667229  0.790034
#
#             effect      year      week       aft  ...      soon       fre  \
# uniqueID                                          ...
# 57325     0.417015 -0.563651 -0.505000  0.515467  ... -0.171358 -0.146099
# 220496    1.061675 -0.563651 -0.505000 -0.567918  ... -0.171358 -0.146099
# 123604   -0.546106 -0.563651  2.819965  1.187223  ... -0.171358 -0.146099
# 175572    1.415865 -0.563651 -0.505000  1.639043  ... -0.171358 -0.146099
# 193559   -0.546106 -0.563651 -0.505000 -0.567918  ... -0.171358 -0.146099
#
#                don        aw     mirac      pack       man      thos     hurt  \
# uniqueID
# 57325    -0.163073 -0.161424 -0.127184 -0.144919 -0.159654 -0.167607 -0.15062
# 220496   -0.163073 -0.161424 -0.127184 -0.144919 -0.159654 -0.167607 -0.15062
# 123604   -0.163073 -0.161424 -0.127184 -0.144919 -0.159654 -0.167607 -0.15062
# 175572   -0.163073 -0.161424 -0.127184 -0.144919 -0.159654 -0.167607 -0.15062
# 193559   -0.163073 -0.161424 -0.127184 -0.144919 -0.159654 -0.167607 -0.15062
#
#               musc
# uniqueID
# 57325    -0.134152
# 220496   -0.134152
# 123604   -0.134152
# 175572   -0.134152
# 193559   -0.134152
#
# [5 rows x 278 columns]

# %%
val_tf_idf.head()
# Out:
#                hav       thi       tak       day      work      pain  \
# uniqueID
# 144223    1.688935 -0.812040  1.655360 -0.618780 -0.475526 -0.411061
# 63395    -0.390324 -0.186066 -0.007619  0.059728 -0.475526 -0.411061
# 6524      0.253691  0.614774 -0.694706 -0.618780 -0.475526 -0.411061
# 68694    -0.893716  0.393303 -0.694706 -0.618780 -0.475526 -0.411061
# 6508     -0.893716  0.212519 -0.694706 -0.618780  0.667805 -0.411061
#
#             effect      year      week       aft  ...      soon       fre  \
# uniqueID                                          ...
# 144223   -0.513294 -0.565498 -0.498609  1.119192  ... -0.169355 -0.156027
# 63395    -0.513294 -0.565498  0.476626  0.423814  ... -0.169355 -0.156027
# 6524     -0.513294 -0.565498 -0.498609 -0.555363  ... -0.169355 -0.156027
# 68694    -0.513294  1.297140 -0.498609 -0.555363  ... -0.169355 -0.156027
# 6508     -0.513294 -0.565498  1.097601 -0.555363  ... -0.169355 -0.156027
#
#                don        aw     mirac      pack       man      thos  \
# uniqueID
# 144223   -0.159174 -0.178245 -0.116408 -0.134026 -0.156543 -0.163192
# 63395    -0.159174 -0.178245 -0.116408 -0.134026 -0.156543 -0.163192
# 6524     -0.159174 -0.178245 -0.116408 -0.134026 -0.156543 -0.163192
# 68694    -0.159174 -0.178245 -0.116408 -0.134026 -0.156543 -0.163192
# 6508     -0.159174 -0.178245 -0.116408 -0.134026 -0.156543 -0.163192
#
#               hurt      musc
# uniqueID
# 144223   -0.153078 -0.126634
# 63395    -0.153078 -0.126634
# 6524     -0.153078 -0.126634
# 68694    -0.153078 -0.126634
# 6508     -0.153078  5.592761
#
# [5 rows x 278 columns]

# %% [markdown]
# ### Word2Vec

# %% [markdown]
# Word2vec is a neural network based approach that represents each word in a corpus as a vector of numeric values. These vectors are called embeddings. The features generated by this method are less interpretable that the other two methods explored previously, since they do not correspond to words themselves.

# %%
from gensim.models import Word2Vec
from tqdm import tqdm
import numpy as np

# %%
def create_word2vec_features(cleaned_x_data, func, min_count = 5, vector_size = 300, window_size = 4):
    
    word2vec = Word2Vec(tokenized_x_train, min_count = min_count, vector_size = vector_size, window = window_size)
    
    agg_embeddings = []
    
    for index in tqdm(range(cleaned_x_data.shape[0])):

        # get the document by index
        document = cleaned_x_data.iloc[index]

        # get word embeddings for the current document in the loop
        # the if condition handles cases where the word is not in the word2vec model 
        # this would include the words that occurred less than 5 times as limited in the code earlier
        embeddings = [word2vec.wv[word] for word in document if word in word2vec.wv]

        # if none of the words have a word embedding, there will be an empty list
        # need 300 dimensions to match the regular cases
        if embeddings == []:
            agg_embeddings.append([0] * 300)
        else:
            # otherwise, just get the mean componentwise across all the word embeddings and append to our list
            agg = func(embeddings, axis = 0)
            agg_embeddings.append(agg)
            
            
    agg_embeddings = [array if isinstance(array, list) else array.tolist() for array in agg_embeddings]
    agg_embeddings = pd.DataFrame(agg_embeddings)
    return agg_embeddings

# %%
tokenized_x_train = x_train.map(lambda x: nltk.word_tokenize(x))
tokenized_x_val = x_val.map(lambda x: nltk.word_tokenize(x))

# %%
word2vec_features_train = create_word2vec_features(tokenized_x_train, np.mean)
word2vec_features_val = create_word2vec_features(tokenized_x_val, np.mean)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 5000/5000 [00:01<00:00, 3687.36it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 5000/5000 [00:01<00:00, 3632.90it/s]

# %% [markdown]
# #### Example of Word2Vec features

# %%
word2vec_features_train.head(10)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.007324  0.204820  0.099299  0.014464  0.075332 -0.281048  0.184437
# 1 -0.139303  0.180754  0.111988  0.078128  0.029294 -0.357636  0.004058
# 2 -0.036586  0.174223  0.152757  0.059488  0.035923 -0.249901  0.082491
# 3 -0.065380  0.115567  0.111259  0.055012  0.009241 -0.302492  0.102125
# 4 -0.106994  0.035152  0.156379  0.066111  0.009210 -0.313795  0.029340
# 5 -0.050738  0.125582  0.086396  0.030312  0.057931 -0.303761  0.051588
# 6  0.007183  0.126765  0.108301  0.090666  0.061449 -0.297487  0.042860
# 7 -0.114893 -0.015272  0.158066  0.049342  0.064707 -0.433323  0.193830
# 8 -0.008963  0.180966  0.073138  0.066673  0.033050 -0.298930  0.158817
# 9  0.025108  0.182698  0.125077  0.075865  0.040381 -0.260624  0.151812
#
#         7         8         9    ...       290       291       292       293  \
# 0  0.441214  0.022711 -0.045729  ... -0.041233  0.317360  0.162645  0.156139
# 1  0.424899 -0.088739 -0.121483  ...  0.040890  0.163661  0.161499  0.034346
# 2  0.406093 -0.080314 -0.054619  ... -0.021716  0.298138  0.212459  0.152045
# 3  0.430253 -0.029085  0.004043  ...  0.046616  0.210835  0.167830  0.078483
# 4  0.450900 -0.082946  0.124165  ...  0.053951  0.228233  0.161105  0.040433
# 5  0.391730  0.007652 -0.019214  ...  0.004301  0.161657  0.122257  0.039549
# 6  0.344469 -0.053608  0.001852  ...  0.017598  0.245088  0.118056  0.044642
# 7  0.405259 -0.116580 -0.060716  ...  0.059809  0.235631  0.259779  0.170410
# 8  0.374329 -0.060642 -0.089056  ... -0.021195  0.271892  0.101639  0.090964
# 9  0.445214 -0.058305 -0.061195  ...  0.000124  0.232864  0.174151  0.123384
#
#         294       295       296       297       298       299
# 0  0.242628  0.100330  0.140747 -0.072593  0.119120 -0.068863
# 1  0.278115  0.234071  0.097365 -0.026282  0.065392 -0.125663
# 2  0.319049  0.200107  0.165291 -0.034495  0.150817 -0.091710
# 3  0.235392  0.181185  0.170695 -0.023468  0.105590 -0.120218
# 4  0.327960  0.169735  0.048082 -0.061951  0.121453  0.003475
# 5  0.207402  0.144604  0.103791 -0.006194  0.027676 -0.172232
# 6  0.216533  0.159801  0.075893 -0.080735  0.139384 -0.094522
# 7  0.274470  0.222915  0.182619  0.092307  0.209132 -0.059821
# 8  0.232042  0.179552  0.048124 -0.037078  0.119219 -0.013868
# 9  0.293057  0.174363  0.141541 -0.022509  0.192795 -0.040069
#
# [10 rows x 300 columns]

# %% [markdown]
# ### Setting up the first test
# The three feature generation methods described above will be used to predict whether a review is positive or negative using a logistic regression model, since this type of model generally takes the least amount of time to train. The feature generation method with the best performance will be selected.
#
# The following functions will be useful in repeatedly creating models and evaluating their performances.

# %%
# This function returns importances from any linear function, such as a logistic regression
def get_linear_importances(linear_model, train_data):
    var_coefs = {var : coef for var, coef in zip(train_data.columns, linear_model.coef_[0])}
    zero_var_coefs =  var_coefs.copy()
    nonzero_var_coefs =  var_coefs.copy()
    for variable, coefficient in var_coefs.items():
        if coefficient != 0:
            del zero_var_coefs[variable]
        if coefficient == 0:
            del nonzero_var_coefs[variable]
            
    sorted_nonzero = {k: v for k, v in sorted(nonzero_var_coefs.items(), key=lambda item: item[1], reverse = True)}
    return sorted_nonzero

# %%
# This function runs the specified model and outputs the results as a tuple, 
# which is intended to be recorded in several dictionaries.
def run_model(title, x_train, y_train, x_val, y_val, model_func, 
              params_dict, search_type = "grid",
              show_plots = True):
    
    def plot_roc(fpr, tpr, title):
        plt.clf()
        plt.plot(fpr, tpr)
        plt.xlabel("FPR")
        plt.ylabel("TPR")
        plt.plot([0, 1], [0, 1], color = 'black', linestyle = "dashed")
        plt.title(title)
        plt.show()
    
    def plot_confusion_matrix(x, y, model, title):
        plt.clf()
        y_prob = model.predict_proba(x)
        yhat = [1 if i >= 0.50 else 0 for i in y_prob[:,1]]
        confusion_matrix = pd.DataFrame(metrics.confusion_matrix(y, yhat), 
                                        columns = ['positive', 'negative'], 
                                        index = ['positive', 'negative'])
        
        confusion_matrix.index.name   = 'Actual'
        confusion_matrix.columns.name = 'Predicted'
        confusion_matrix              = sns.heatmap(confusion_matrix, 
                                                    annot = True, 
                                                    square = True,
                                                    fmt = 'g', 
                                                    cmap = sns.diverging_palette(20,220,n=200)).set_title(title)
        plt.show()
    
        
    
    # if only one value for the parameters is provided, the grid/randomized search will not actually do anything

    print("    Running model using specified parameters")
    
    if search_type == "randomized":
        model = RandomizedSearchCV(model_func(), 
                                         params_dict,
                                         n_jobs = 4, 
                                         scoring = "roc_auc",
                                         n_iter = 100,
                                         random_state = 0)
        
    elif search_type == "grid":
        model = GridSearchCV(model_func(), 
                                   params_dict,
                                   n_jobs = 4,
                                   scoring = "roc_auc")
        

        
    start = time.time()
    model.fit(x_train, y_train)
    end = time.time()
    
    training_time = (end - start)
    
    # Redefines the model as the best estimator model
    best_params = model.best_params_
    
    model = model.best_estimator_
    
    if model_func in [LogisticRegression, LogisticRegressionCV]:
        importances = get_linear_importances(model, x_train)
    elif model_func == BernoulliNB:
        importances = None
    else:
        importances = pd.DataFrame(index = x_train.columns, 
                                    data  = {method + '_imp' : model.feature_importances_})
    
    print("    Calculating Metrics")
    
    # predictions
    y_hat_train = model.predict(x_train)
    y_hat_val = model.predict(x_val)
    
    # probabilities
    y_train_prob = model.predict_proba(x_train)
    y_val_prob = model.predict_proba(x_val)

    # roc curves
    fpr_train, tpr_train, thresholds = metrics.roc_curve(y_train, y_train_prob[:,1], pos_label = 1)
    fpr_val, tpr_val, thresholds = metrics.roc_curve(y_val, y_val_prob[:,1], pos_label = 1)
    
    
    
    train_metrics = {
    'training_time' : training_time,
    'accuracy'      : metrics.accuracy_score(y_train, y_hat_train),
    'precision'     : metrics.precision_score(y_train, y_hat_train),
    'recall'        : metrics.recall_score(y_train, y_hat_train),
    'f1'            : metrics.f1_score(y_train, y_hat_train),
    'auc'           : metrics.auc(fpr_train, tpr_train)
    }
    
    test_metrics = {
    'training_time' : training_time,
    'accuracy'      : metrics.accuracy_score(y_val, y_hat_val),
    'precision'     : metrics.precision_score(y_val, y_hat_val),
    'recall'        : metrics.recall_score(y_val, y_hat_val),
    'f1'            : metrics.f1_score(y_val, y_hat_val),
    'auc'           : metrics.auc(fpr_val, tpr_val)
    }
    
    
    if show_plots:
        plot_roc(fpr_train, tpr_train, title + ' Training ROC')
        plot_roc(fpr_val, tpr_val, title + ' Validation ROC')
        plot_confusion_matrix(x_train, y_train, model, title + ' Training Confusion Matrix')
        plot_confusion_matrix(x_val, y_val, model, title + ' Validation Confusion Matrix')
    
    return importances, train_metrics, test_metrics, best_params, model

# %% [markdown]
# ### Ngram selection

# %% [markdown]
# Before evaluating feature generation methods (BOW, TF-IDF, and Word2vec) against each other, it must first be determined which ngram range is optimal for use in BOW and TF-IDF. The results of this test will determine whether BOW, and TF-IDF features are generated based on unigrams, bigrams, trigrams, or a combination of any of the three.
#
# For example, using a n-gram range from 1 to 2 means that features will be generated from both unigram and bigram tokens.
#
# N-gram Range = (1, 2)
#
# Text = “an apple a day keeps the doctor away”
#
# Becomes:
#
# ['an', 'apple', ‘a’, 'day', 'keeps', 'the', 'doctor', 'away', 'an apple', ‘apple a’, 'a day', 'day keeps', 'keeps the' , 'the doctor' , 'doctor away']

# %%
def gen_ngram_grid():
    ngram_combos = []
    for i in (1,2):
        for o in (1,2):
            if not i > o:
                combo = (i, o)
                ngram_combos.append(combo)
    return ngram_combos

# %%
ngram_search_grid = gen_ngram_grid()
ngram_search_grid
# Out:
# [(1, 1), (1, 2), (2, 2)]

# %% [markdown]
# #### Bag of Words ngram selection

# %% [markdown]
# Here, the create_bow_features function is called for each ngram in the ngram search grid. The generated features are used in a logistic regression model to predictict positivity class using the run_model function. The outputs of the run_model function, such as feature importances, the best hyperparameters (which is irrelevant in this case), evaluation metrics for the training and test sets, and the fit model itself, are each stored in their own dictionary.
#
# Only half of the training data will be used in this step to speed up training time.

# %%
splits = 2

# %%
x_train_first_slice = np.array_split(x_train,splits)[0]
x_val_first_slice = np.array_split(x_val,splits)[0]
y_train_first_slice = np.array_split(y_train,splits)[0]
y_val_first_slice = np.array_split(y_val,splits)[0]

# %%
importances_bow_ngrams    = {}
train_metrics_bow_ngrams  = {}
test_metrics_bow_ngrams   = {}
best_params_bow_ngrams    = {}
fit_models_bow_ngrams     = {}


# Since the GridSearchCV function is used to pass the parameters to the model function in the run_model function below,
# a range must be specified in the params dictionary even if only one value is being passed.

params = {
            'random_state' : [0], 
            'penalty'      : ["l1"], 
            'solver'       : ["liblinear"],
            'max_iter'     : [1000]
        }

for ngram_combo in ngram_search_grid:
    train_data, val_data = create_bow_features(x_train_first_slice, x_val_first_slice, ngram_range = ngram_combo)
    print("Now on", str(ngram_combo))
    
    loc = str(ngram_combo)
    
    try:
        (importances_bow_ngrams[loc], 
         train_metrics_bow_ngrams[loc], 
         test_metrics_bow_ngrams[loc], 
         best_params_bow_ngrams[loc], 
         fit_models_bow_ngrams[loc])         = run_model(loc, 
                                                         train_data,
                                                         y_train_first_slice,
                                                         val_data,
                                                         y_val_first_slice,
                                                         LogisticRegressionCV,
                                                         params)
    
    except Exception as e:
        print("Could not run", loc, "due to", e)
# Out:
# Now on (1, 1)
#     Running model using specified parameters
#     Calculating Metrics
# Now on (1, 2)
#     Running model using specified parameters
#     Calculating Metrics
# Now on (2, 2)
#     Running model using specified parameters
#     Calculating Metrics

# %% [markdown]
# ##### Performance statistics for each run:

# %% [markdown]
# ##### Train

# %%
train_metricsdf = pd.DataFrame(train_metrics_bow_ngrams).transpose()
train_metricsdf
# Out:
#         training_time  accuracy  precision    recall        f1       auc
# (1, 1)     117.605163    0.8344   0.826764  0.966989  0.891396  0.914827
# (1, 2)      87.953814    0.8800   0.868488  0.977234  0.919657  0.960393
# (2, 2)     137.462115    0.8256   0.817091  0.968697  0.886458  0.923713

# %% [markdown]
# ##### Test

# %%
test_metricsdf = pd.DataFrame(test_metrics_bow_ngrams).transpose()
test_metricsdf
# Out:
#         training_time  accuracy  precision    recall        f1       auc
# (1, 1)     117.605163    0.7508   0.772394  0.908986  0.835142  0.798911
# (1, 2)      87.953814    0.7680   0.783333  0.920507  0.846398  0.812727
# (2, 2)     137.462115    0.7384   0.752568  0.928571  0.831356  0.754646

# %% [markdown]
# ##### Conclusion:

# %%
best_bow_ngram_range = test_metricsdf.auc.idxmax()
print("The best performing ngram range for BOW is:", best_bow_ngram_range)
# Out:
# The best performing ngram range for BOW is: (1, 2)

# %% [markdown]
# #### TF-IDF ngram selection

# %% [markdown]
# The same process as above is repeated for TF-IDF selection

# %%
importances_tf_idf_ngrams    = {}
train_metrics_tf_idf_ngrams   = {}
test_metrics_tf_idf_ngrams   = {}
best_params_tf_idf_ngrams     = {}
fit_models_tf_idf_ngrams     = {}

params = {
            'random_state' : [0], 
            'penalty'      : ["l1"], 
            'solver'       : ["liblinear"],
            'max_iter'     : [1000]
        }

for ngram_combo in ngram_search_grid:
    train_data, val_data = create_tf_idf_features(x_train_first_slice, x_val_first_slice, ngram_range = ngram_combo)
    print("Now on", str(ngram_combo))
    
    loc = str(ngram_combo)
    
    try:
        (importances_tf_idf_ngrams[loc], 
         train_metrics_tf_idf_ngrams[loc], 
         test_metrics_tf_idf_ngrams[loc], 
         best_params_tf_idf_ngrams[loc], 
         fit_models_tf_idf_ngrams[loc])          = run_model(loc, 
                                                             train_data,
                                                             y_train_first_slice,
                                                             val_data,
                                                             y_val_first_slice,
                                                             LogisticRegressionCV,
                                                             params)
        
    except Exception as e:
        print("Could not run", loc, "due to", e)
# Out:
# Now on (1, 1)
#     Running model using specified parameters
#     Calculating Metrics
# Now on (1, 2)
#     Running model using specified parameters
#     Calculating Metrics
# Now on (2, 2)
#     Running model using specified parameters
#     Calculating Metrics

# %% [markdown]
# ##### Performance statistics for each run:

# %% [markdown]
# ##### Train

# %%
train_metricsdf = pd.DataFrame(train_metrics_tf_idf_ngrams).transpose()
train_metricsdf
# Out:
#         training_time  accuracy  precision    recall        f1       auc
# (1, 1)       2.898036    0.7696   0.786511  0.922595  0.849136  0.800898
# (1, 2)       1.530351    0.7200   0.730685  0.952760  0.827075  0.682029
# (2, 2)       0.171982    0.7028   0.702800  1.000000  0.825464  0.500000

# %% [markdown]
# ##### Test

# %%
test_metricsdf = pd.DataFrame(test_metrics_tf_idf_ngrams).transpose()
test_metricsdf
# Out:
#         training_time  accuracy  precision    recall        f1       auc
# (1, 1)       2.898036    0.7384   0.766765  0.895737  0.826249  0.731610
# (1, 2)       1.530351    0.6964   0.715103  0.935484  0.810581  0.647726
# (2, 2)       0.171982    0.6944   0.694400  1.000000  0.819641  0.500000

# %% [markdown]
# ##### Conclusion

# %% [markdown]
# The best performing ngram range for TF IDF is: (1,1)
#
# This ngram range includes only unigrams.

# %%
best_tf_idf_ngram_range = test_metricsdf.auc.idxmax()
print("The best performing ngram range for TF-IDF is:", best_tf_idf_ngram_range)
# Out:
# The best performing ngram range for TF-IDF is: (1, 1)

# %% [markdown]
# ## Feature generation method selection
# Now that the optimal ngram ranges to use in BOW and TF-IDF have been identified, training and validation datasets can be generated using each method (using the optimal ngrams). In order to speed up training time in this step, again only half of the training data will be used. The model generated by this step is not related to the final predictive model other than its usefulness in selecting a feature set.
#
# Recall that the three methods being evaluated are:
# 1. Bag of words (BOW)
# 2. Term frequency-inverse document frequency (TF-IDF)
# 3. Word2vec

# %%
bow_train, bow_val = create_bow_features(x_train, x_val, ngram_range = eval(best_bow_ngram_range))
tf_idf_train, tf_idf_val = create_tf_idf_features(x_train, x_val, ngram_range = eval(best_tf_idf_ngram_range))

# %%
train_data = { 
              'bag_of_words' : bow_train,
              'tf_idf'       : tf_idf_train,
              'word2vec'     : word2vec_features_train
             }

val_data = { 
              'bag_of_words' : bow_val,
              'tf_idf'       : tf_idf_val,
              'word2vec'     : word2vec_features_val
            }

# %%
importances_features_all   = {}
train_metrics_features_all  = {}
test_metrics_features_all   = {}
best_params_features_all   = {}
fit_models_features_all    = {}


params = {
            'random_state' : [0], 
            'penalty'      : ["l1"], 
            'solver'       : ["liblinear"],
            'max_iter'     : [1000]
        }

for method, train_dataset in train_data.items():
    
    # Split the data according to the number of splits defined earlier in order to speed training time
    train = np.array_split(train_dataset,splits)[0]
    val   = np.array_split(val_data[method],splits)[0]
    
    print(method + ":")
    try:
        (importances_features_all[method], 
         train_metrics_features_all[method], 
         test_metrics_features_all[method], 
         best_params_features_all[method], 
         fit_models_features_all[method])         = run_model(method, 
                                                             train,
                                                             y_train_first_slice,
                                                             val,
                                                             y_val_first_slice,
                                                             LogisticRegressionCV,
                                                             params)
        
        
    except Exception as e: 
        print("Could not run", method, "due to", e)
# Out:
# bag_of_words:
#     Running model using specified parameters
#     Calculating Metrics
# tf_idf:
#     Running model using specified parameters
#     Calculating Metrics
# word2vec:
#     Running model using specified parameters
#     Calculating Metrics

# %% [markdown]
# ##### Performance statistics
#
# ##### Train

# %%
train_metricsdf = pd.DataFrame(train_metrics_features_all).transpose()
train_metricsdf
# Out:
#               training_time  accuracy  precision    recall        f1       auc
# bag_of_words     113.301573    0.9988   0.998295  1.000000  0.999147  0.999995
# tf_idf             9.216099    0.8232   0.843701  0.918611  0.879564  0.875739
# word2vec       13023.110682    0.8068   0.820423  0.928287  0.871028  0.850512

# %% [markdown]
# ##### Test

# %%
test_metricsdf = pd.DataFrame(test_metrics_features_all).transpose()
test_metricsdf
# Out:
#               training_time  accuracy  precision    recall        f1       auc
# bag_of_words     113.301573    0.7404   0.804482  0.827189  0.815677  0.779803
# tf_idf             9.216099    0.7684   0.803038  0.883065  0.841152  0.790696
# word2vec       13023.110682    0.6828   0.694915  0.968318  0.809146  0.523629

# %% [markdown]
# ##### Conclusion

# %% [markdown]
# TF-IDF is the best performing feature generation method because it has a much lower training time than bag of words while still offering a comparable test AUC. Word2vec is clearly a poor choice as a feature generation method.

# %%
best_features_method = 'tf_idf'

# %%
train_data = train_data[best_features_method]
val_data = val_data[best_features_method]

# %% [markdown]
# ##### Features dataset generated from reviews data:

# %%
train_data.head()
# Out:
#                hav       thi       tak       day      work      pain  \
# uniqueID
# 57325     0.176254 -0.777215  2.496794  2.549079  1.174017  0.445719
# 220496    1.808628  1.527987 -0.708877 -0.616428 -0.517721 -0.413207
# 123604   -0.909089  1.459920 -0.708877  0.665644  0.852631  0.978298
# 175572   -0.356352 -0.073957  0.107406  1.801738  0.343838 -0.413207
# 193559   -0.909089 -0.777215 -0.708877  0.492185  0.667229  0.790034
#
#             effect      year      week       aft  ...      soon       fre  \
# uniqueID                                          ...
# 57325     0.417015 -0.563651 -0.505000  0.515467  ... -0.171358 -0.146099
# 220496    1.061675 -0.563651 -0.505000 -0.567918  ... -0.171358 -0.146099
# 123604   -0.546106 -0.563651  2.819965  1.187223  ... -0.171358 -0.146099
# 175572    1.415865 -0.563651 -0.505000  1.639043  ... -0.171358 -0.146099
# 193559   -0.546106 -0.563651 -0.505000 -0.567918  ... -0.171358 -0.146099
#
#                don        aw     mirac      pack       man      thos     hurt  \
# uniqueID
# 57325    -0.163073 -0.161424 -0.127184 -0.144919 -0.159654 -0.167607 -0.15062
# 220496   -0.163073 -0.161424 -0.127184 -0.144919 -0.159654 -0.167607 -0.15062
# 123604   -0.163073 -0.161424 -0.127184 -0.144919 -0.159654 -0.167607 -0.15062
# 175572   -0.163073 -0.161424 -0.127184 -0.144919 -0.159654 -0.167607 -0.15062
# 193559   -0.163073 -0.161424 -0.127184 -0.144919 -0.159654 -0.167607 -0.15062
#
#               musc
# uniqueID
# 57325    -0.134152
# 220496   -0.134152
# 123604   -0.134152
# 175572   -0.134152
# 193559   -0.134152
#
# [5 rows x 278 columns]

# %%
val_data.head()
# Out:
#                hav       thi       tak       day      work      pain  \
# uniqueID
# 144223    1.688935 -0.812040  1.655360 -0.618780 -0.475526 -0.411061
# 63395    -0.390324 -0.186066 -0.007619  0.059728 -0.475526 -0.411061
# 6524      0.253691  0.614774 -0.694706 -0.618780 -0.475526 -0.411061
# 68694    -0.893716  0.393303 -0.694706 -0.618780 -0.475526 -0.411061
# 6508     -0.893716  0.212519 -0.694706 -0.618780  0.667805 -0.411061
#
#             effect      year      week       aft  ...      soon       fre  \
# uniqueID                                          ...
# 144223   -0.513294 -0.565498 -0.498609  1.119192  ... -0.169355 -0.156027
# 63395    -0.513294 -0.565498  0.476626  0.423814  ... -0.169355 -0.156027
# 6524     -0.513294 -0.565498 -0.498609 -0.555363  ... -0.169355 -0.156027
# 68694    -0.513294  1.297140 -0.498609 -0.555363  ... -0.169355 -0.156027
# 6508     -0.513294 -0.565498  1.097601 -0.555363  ... -0.169355 -0.156027
#
#                don        aw     mirac      pack       man      thos  \
# uniqueID
# 144223   -0.159174 -0.178245 -0.116408 -0.134026 -0.156543 -0.163192
# 63395    -0.159174 -0.178245 -0.116408 -0.134026 -0.156543 -0.163192
# 6524     -0.159174 -0.178245 -0.116408 -0.134026 -0.156543 -0.163192
# 68694    -0.159174 -0.178245 -0.116408 -0.134026 -0.156543 -0.163192
# 6508     -0.159174 -0.178245 -0.116408 -0.134026 -0.156543 -0.163192
#
#               hurt      musc
# uniqueID
# 144223   -0.153078 -0.126634
# 63395    -0.153078 -0.126634
# 6524     -0.153078 -0.126634
# 68694    -0.153078 -0.126634
# 6508     -0.153078  5.592761
#
# [5 rows x 278 columns]

# %% [markdown]
# #### Importances

# %%
importancesdf = pd.DataFrame(index = importances_features_all[best_features_method].keys(), 
                                 data = importances_features_all[best_features_method].values(),
                                 columns = ['coef_value'])
print("Negative words:")
print(importancesdf.head(10), "\n")
print("Positive words:")
print(importancesdf.sort_values(by='coef_value', ascending = True).head(10), "\n")
most_helpful_negative = importancesdf.idxmax()[0]
most_helpful_not_negative = importancesdf.idxmin()[0]
print("The lemmatized word/bigram most useful in predicting negative reviews is:",
     most_helpful_negative, "\n",
     "and the lemmatized word/bigram most useful in predicting non-negative reviews is:",
     most_helpful_not_negative)
# Out:
# Negative words:
#        coef_value
# lov      0.559581
# sav      0.495825
# amaz     0.404269
# wond     0.378035
# best     0.341868
# lif      0.283359
# mirac    0.234120
# high     0.231651
# gre      0.221601
# worry    0.213397
#
# Positive words:
#         coef_value
# wors     -0.336259
# stop     -0.322453
# thi      -0.216102
# caus     -0.212892
# did      -0.199296
# al       -0.195497
# worst    -0.186311
# chang    -0.181394
# anoth    -0.178033
# extrem   -0.175715
#
# The lemmatized word/bigram most useful in predicting negative reviews is: lov
#  and the lemmatized word/bigram most useful in predicting non-negative reviews is: wors

# %% [markdown]
# ## Feature Engineering
# To improve the model further, additional features will be generated from the information already present in this dataset, including from the review itself. These new features will be:
# 1. A dummy variable for year
# 2. Rating month
# 3. Rating day of month
# 4. Rating day of week
# 5. Unique drug competitors named
# 6. Total number of competitors of the drug being reviewed
# 7. Total number of times that competing drugs are mentioned in the review
# 8. Total number of times the drug being reviewed is mentioned in the review
# 9. Proportion of all competitors named in the review
# 10. Ratio of mentions between the drug being reviewed and competing drugs
#
# (All numeric)

# %% [markdown]
# ##### Generating new features

# %% [markdown]
# Ensure that no errors have occured while running this notebook by comparing the indexes of these datasets:

# %% [markdown]
# Selecting a training subset:

# %%
all(train_data.index == x_train.index) & all(val_data.index == x_val.index)
# Out:
# True

# %%
x_train = drug_reviews.loc[train_data.index]
x_train.head()
# Out:
#                  drugName      condition  \
# uniqueID
# 57325         Oxymorphone           Pain
# 220496     Loestrin 24 Fe  Birth Control
# 123604              Skyla  Birth Control
# 175572          Augmentin      Sinusitis
# 193559    Cyclobenzaprine   Muscle Spasm
#
#                                                      review  rating  \
# uniqueID
# 57325     After breaking my neck and back in a car accid...       8
# 220496    I am 29 and I have never been in birth control...      10
# 123604    I've had this for 7 months now. I got it 8 wee...      10
# 175572    I was prescribed Augmfnyin 875 twice a day for...       8
# 193559    I injured my back and it took me 4 days to vis...       3
#
#                date  usefulCount  \
# uniqueID
# 57325     21-May-14           14
# 220496    14-Aug-11            1
# 123604     6-Jul-17            4
# 175572     7-Jan-15           76
# 193559     5-Nov-09           27
#
#                                              cleaned_review
# uniqueID
# 57325     aft break my neck and back in a car accid i wa...
# 220496    i am 29 and i hav nev been in bir control bef ...
# 123604    i 've had thi for 7 month now . i got it 8 wee...
# 175572    i was prescrib augmfnyin 875 twic a day for a ...
# 193559    i ind my back and it took me 4 day to visit th...

# %% [markdown]
# Selecting a test subset:

# %%
x_val = drug_reviews.loc[val_data.index]
x_val.head()
# Out:
#                                        drugName                  condition  \
# uniqueID
# 144223                             Etonogestrel              Birth Control
# 63395                                    Epiduo                       Acne
# 6524      Sodium biphosphate / sodium phosphate          Bowel Preparation
# 68694                       Medroxyprogesterone  Abnormal Uterine Bleeding
# 6508                              Wellbutrin XL                 Depression
#
#                                                      review  rating  \
# uniqueID
# 144223    I love the nextplanon so far. My arm was a lit...      10
# 63395     I am currently taking Minocycline and I just g...       8
# 6524      Just used this product for first time in prepa...       9
# 68694     Took the depo shot for the first time earlier ...       1
# 6508      Been on it for one week. 150XL dry mouth. Lost...       4
#
#                date  usefulCount  \
# uniqueID
# 144223    28-May-16            4
# 63395     24-Aug-16            3
# 6524       1-Dec-16            5
# 68694     29-Mar-17            6
# 6508       2-Jul-17           12
#
#                                              cleaned_review
# uniqueID
# 144223    i lov the nextplanon so far . my arm was a lit...
# 63395     i am cur tak minocycline and i just got a fac ...
# 6524      just us thi produc for first tim in prep for h...
# 68694     took the depo shot for the first tim ear thi y...
# 6508      been on it for on week . 150xl dry mou . lost ...

# %% [markdown]
# A function which creates a dictionary of all conditions and the drugs that treat them, based on the data available:

# %%
def drugs_by_condition():
    all_conditions = drug_reviews.condition.drop_duplicates()
    all_drug_conditions_dict = {}

    for condition in list(all_conditions):
        drugs_in_condition = drug_reviews.loc[drug_reviews.condition == condition, 'drugName'].drop_duplicates()
        all_drug_conditions_dict[condition] = list(drugs_in_condition)
    
    return all_drug_conditions_dict

all_drug_conditions_dict = drugs_by_condition()
list(all_drug_conditions_dict.keys())[1:10]
# Out:
# {'Left Ventricular Dysfunction': ['Valsartan', 'Coreg'],
#  'ADHD': ['Guanfacine',
#   'Daytrana',
#   'Intuniv',
#   'Focalin',
#   'Vyvanse',
#   'Lisdexamfetamine',
#   'Amphetamine / dextroamphetamine',
#   'Atomoxetine',
#   'Concerta',
#   'Strattera',
#   'Focalin XR',
#   'Methylphenidate',
#   'Ritalin',
#   'Kapvay',
#   'Adderall',
#   'Bupropion',
#   'Dexmethylphenidate',
#   'Wellbutrin SR',
#   'Zenzedi',
#   'Desoxyn',
#   'Adderall XR',
#   'Adzenys XR-ODT',
#   'Pemoline',
#   'Nuvigil',
#   'Dyanavel XR',
#   'Dextroamphetamine',
#   'Methylin ER',
#   'Dexedrine',
#   'Amphetamine',
#   'Quillivant XR',
#   'Omega-3 polyunsaturated fatty acids'],
#  'Birth Control': ['Lybrel',
#   'Ortho Evra',
#   'Ethinyl estradiol / levonorgestrel',
#   'Nexplanon',
#   'Etonogestrel',
#   'Implanon',
#   'Drospirenone / ethinyl estradiol',
#   'NuvaRing',
#   'Gildess Fe 1 / 20',
#   'Lo Loestrin Fe',
#   'Levonorgestrel',
#   'Sronyx',
#   'Jolivette',
#   'Aviane',
#   'Depo-Provera',
#   'Ethinyl estradiol / norgestimate',
#   'Mirena',
#   'Ethinyl estradiol / norelgestromin',
#   'Reclipsen',
#   'Skyla',
#   'Ortho Tri-Cyclen',
#   'Ethinyl estradiol / norethindrone',
#   'Seasonique',
#   'Liletta',
#   'Medroxyprogesterone',
#   'Levora',
#   'ParaGard',
#   'Ocella',
#   'Copper',
#   'Microgestin Fe 1 / 20',
#   'Blisovi Fe 1 / 20',
#   'Loestrin 24 Fe',
#   'Junel Fe 1 / 20',
#   'Sprintec',
#   'Ortho Tri-Cyclen Lo',
#   'Orsythia',
#   'Ethinyl estradiol / etonogestrel',
#   'Depo-Provera Contraceptive',
#   'TriNessa',
#   'Yaz',
#   'Norethindrone',
#   'Minastrin 24 Fe',
#   'Mononessa',
#   'Jolessa',
#   'Cryselle',
#   'Sharobel',
#   'Apri',
#   'Velivet',
#   'Necon 1 / 35',
#   'Nora-Be',
#   'Kyleena',
#   'Camrese',
#   'Junel Fe 1.5 / 30',
#   'Desogestrel / ethinyl estradiol',
#   'Beyaz',
#   'Errin',
#   'Estarylla',
#   'Ethinyl estradiol / norgestrel',
#   'Lutera',
#   'LoSeasonique',
#   'Ortho Cyclen',
#   'Xulane',
#   'Alesse',
#   'Tri-Lo-Sprintec',
#   'Tri-Previfem',
#   'Aubra',
#   'Tri-Sprintec',
#   'Drospirenone / ethinyl estradiol / levomefolate calcium',
#   'Blisovi 24 Fe',
#   'Portia',
#   'Viorele',
#   'Lyza',
#   'Previfem',
#   'Microgestin 1 / 20',
#   'Zarah',
#   'Heather',
#   'Loestrin Fe 1.5 / 30',
#   'Chateal',
#   'Taytulla',
#   'Generess Fe',
#   'Lo / Ovral-28',
#   'Seasonale',
#   'Tarina Fe 1 / 20',
#   'Yasmin',
#   'Quasense',
#   'Pimtrea',
#   'Vestura',
#   'Nortrel 1 / 35',
#   'Safyral',
#   'Ortho-Novum 1 / 35',
#   'Microgestin Fe 1.5 / 30',
#   'Gianvi',
#   'Kariva',
#   'Ortho Micronor',
#   'Mibelas 24 Fe',
#   'Necon 1 / 50',
#   'Gildess 24 Fe',
#   'Lessina',
#   'Cyclafem 1 / 35',
#   'Zovia',
#   'Necon 7 / 7 / 7',
#   'Desogen',
#   'Cyred',
#   'Loestrin 21 1 / 20',
#   'Dienogest / estradiol'],
#  'Opiate Dependence': ['Buprenorphine / naloxone',
#   'Naltrexone',
#   'Suboxone',
#   'Buprenorphine',
#   'Vivitrol',
#   'Bunavail',
#   'Subutex'],
#  'Benign Prostatic Hyperplasia': ['Cialis',
#   'Tamsulosin',
#   'Cardura XL',
#   'Silodosin',
#   'Dutasteride',
#   'Tadalafil',
#   'Rapaflo',
#   'Flomax',
#   'Alfuzosin',
#   'Terazosin',
#   'Finasteride',
#   'Jalyn'],
#  'Emergency Contraception': ['Levonorgestrel',
#   'Plan B One-Step',
#   'Ulipristal',
#   'Plan B',
#   'EContra EZ',
#   'ella',
#   'My Way',
#   'Next Choice',
#   'Opcicon One-Step',
#   'Aftera'],
#  'Bipolar Disorde': ['Aripiprazole',
#   'Lamotrigine',
#   'Symbyax',
#   'Latuda',
#   'Lithium',
#   'Lamictal',
#   'Olanzapine',
#   'Lurasidone',
#   'Depakote',
#   'Ziprasidone',
#   'Saphris',
#   'Quetiapine',
#   'Seroquel',
#   'Sertraline',
#   'Klonopin',
#   'Carbamazepine',
#   'Zyprexa',
#   'Seroquel XR',
#   'Wellbutrin',
#   'Divalproex sodium',
#   'Effexor',
#   'Geodon',
#   'Invega',
#   'Depakote ER',
#   'Neurontin',
#   'Abilify',
#   'Asenapine',
#   'Oxcarbazepine',
#   'Risperdal',
#   'Clonazepam',
#   'Risperidone',
#   'Zyprexa Zydis',
#   'Lexapro',
#   'Tegretol',
#   'Trileptal',
#   'Clonidine',
#   'Escitalopram',
#   'Topamax',
#   'Iloperidone',
#   'Gabapentin',
#   'Bupropion',
#   'Cariprazine',
#   'Citalopram',
#   'Topiramate',
#   'Epitol',
#   'Venlafaxine',
#   'Eskalith',
#   'Desvenlafaxine',
#   'Effexor XR',
#   'Fluoxetine / olanzapine'],
#  'Epilepsy': ['Keppra',
#   'Carbamazepine',
#   'Levetiracetam',
#   'Carbatrol',
#   'Mephobarbital',
#   'Lamotrigine',
#   'Depakote',
#   'Perampanel',
#   'Divalproex sodium',
#   'Mebaral',
#   'Depakote ER',
#   'Felbatol'],
#  'Migraine Prevention': ['Topiramate',
#   'Amitriptyline',
#   'Topamax',
#   'OnabotulinumtoxinA',
#   'Botox',
#   'Zonisamide',
#   'Propranolol',
#   'Elavil',
#   'Vitamin B2',
#   'Clonazepam',
#   'Divalproex sodium',
#   'Nortriptyline',
#   'Bupropion',
#   'Atenolol',
#   'Nadolol'],
#  'Depression': ['L-methylfolate',
#   'Sertraline',
#   'Venlafaxine',
#   'Effexor XR',
#   'Wellbutrin',
#   'Aripiprazole',
#   'Desvenlafaxine',
#   'Fluoxetine',
#   'Bupropion',
#   'Trintellix',
#   'Trazodone',
#   'Pristiq',
#   'Levomilnacipran',
#   'Cymbalta',
#   'Escitalopram',
#   'Nardil',
#   'Zoloft',
#   'Methylphenidate',
#   'Wellbutrin XL',
#   'Lexapro',
#   'Viibryd',
#   'Effexor',
#   'Zyprexa',
#   'Duloxetine',
#   'Rexulti',
#   'Quetiapine',
#   'Citalopram',
#   "St. john's wort",
#   'Vilazodone',
#   'Emsam',
#   'Celexa',
#   'Vortioxetine',
#   'Paxil',
#   'Prozac',
#   'Lamotrigine',
#   'Isocarboxazid',
#   'Limbitrol',
#   'Paroxetine',
#   'Deplin',
#   'Serzone',
#   'Xanax',
#   'Parnate',
#   'Elavil',
#   'Wellbutrin SR',
#   'Remeron',
#   'Brexpiprazole',
#   'S-adenosylmethionine',
#   'Nefazodone',
#   'Abilify',
#   'Amitriptyline',
#   'Selegiline',
#   'Alprazolam',
#   'Tramadol',
#   'Fluvoxamine',
#   'Seroquel',
#   'Olanzapine',
#   'Oleptro',
#   'Symbyax',
#   'Mirtazapine',
#   'Desipramine',
#   'Seroquel XR',
#   'Imipramine',
#   'Phenelzine',
#   'Nortriptyline',
#   'Modafinil',
#   'Tranylcypromine',
#   'Nuvigil',
#   'Fetzima',
#   'Risperidone',
#   'Tryptophan',
#   'Niacin',
#   'Paxil CR'],
#  "Crohn's Disease": ['Pentasa',
#   'Colazal',
#   'Vedolizumab',
#   'Mesalamine',
#   'Imuran',
#   'Entyvio',
#   'Sulfasalazine',
#   'Budesonide'],
#  'Cough': ['Dextromethorphan',
#   'Benzonatate',
#   'Tylenol with Codeine #3',
#   'Codeine / guaifenesin',
#   'Delsym 12 Hour Cough Relief',
#   'Guaifenesin',
#   'Hydromet',
#   'Delsym',
#   'Cheratussin AC',
#   'Mucinex',
#   'Chlorpheniramine / hydrocodone',
#   'Codeine / promethazine',
#   'Robitussin CoughGels Long-Acting',
#   'Tessalon Perles',
#   'Acetaminophen / hydrocodone',
#   'Tussionex Pennkinetic',
#   'Homatropine / hydrocodone'],
#  'Obesity': ['Liraglutide',
#   'Contrave',
#   'Phentermine / topiramate',
#   'Saxenda',
#   'Lorcaserin',
#   'Bontril Slow Release',
#   'Bupropion / naltrexone',
#   'Xenical',
#   'Orlistat',
#   'Victoza',
#   'Diethylpropion',
#   'Pristiq',
#   'Belviq',
#   'Phentermine',
#   'Topiramate',
#   'Qsymia',
#   'Phendimetrazine',
#   'Alli',
#   'Tenuate',
#   'Didrex',
#   'Benzphetamine',
#   'Bontril PDM',
#   'Meridia',
#   'Topamax',
#   'Adipex-P'],
#  'Urinary Tract Infection': ['Trimethoprim',
#   'Doxycycline',
#   'Macrobid',
#   'Nitrofurantoin',
#   'Levaquin',
#   'Sulfamethoxazole / trimethoprim',
#   'Bactrim DS',
#   'Cipro',
#   'Uribel',
#   'Bactrim',
#   'Amoxicillin',
#   'Rocephin',
#   'Ciprofloxacin',
#   'Levofloxacin',
#   'Hyoscyamine / methenamine / methylene blue / phenyl salicylate',
#   'Acetohydroxamic acid',
#   'Septra'],
#  'ibromyalgia': ['Amitriptyline',
#   'Milnacipran',
#   'Topiramate',
#   'Fluoxetine',
#   'Flexeril',
#   'Trazodone',
#   'Duloxetine',
#   'Meloxicam',
#   'Topamax',
#   'Savella',
#   'Pregabalin',
#   'Cyclobenzaprine',
#   'Gabapentin',
#   'Pristiq',
#   'Lyrica',
#   'Desvenlafaxine',
#   'Tramadol',
#   'Ultram',
#   'Prednisone',
#   'Mucinex',
#   'Desyrel',
#   'Cymbalta',
#   'Naltrexone',
#   'Metaxalone',
#   'Guaifenesin',
#   'Ultram ER'],
#  'Chronic Myelogenous Leukemia': ['Nilotinib',
#   'Sprycel',
#   'Tasigna',
#   'Dasatinib',
#   'Imatinib',
#   'Gleevec'],
#  'HIV Infection': ['Atripla',
#   'Efavirenz / emtricitabine / tenofovir',
#   'Raltegravir',
#   'Cobicistat / elvitegravir / emtricitabine / tenofovir',
#   'Genvoya',
#   'Dolutegravir',
#   'Abacavir / dolutegravir / lamivudine',
#   'Complera',
#   'Cobicistat / elvitegravir / emtricitabine / tenofovir alafenamide',
#   'Lopinavir / ritonavir',
#   'Sustiva',
#   'Emtricitabine / rilpivirine / tenofovir',
#   'Prezcobix',
#   'Stribild',
#   'Maraviroc',
#   'Triumeq',
#   'Atazanavir'],
#  'Insomnia': ['Trazodone',
#   'Amitriptyline',
#   'Mirtazapine',
#   'Zolpidem',
#   'Quetiapine',
#   'Ramelteon',
#   'Suvorexant',
#   'Ambien',
#   'Diphenhydramine',
#   'Rozerem',
#   'Restoril',
#   'Lorazepam',
#   'Clonazepam',
#   'Secobarbital',
#   'Tryptophan',
#   'Lunesta',
#   'Temazepam',
#   'Chloral hydrate',
#   'Melatonin',
#   'Belsomra',
#   'Elavil',
#   'Unisom SleepGels',
#   'Gabapentin',
#   'Klonopin',
#   'Silenor',
#   'Flurazepam',
#   'Neurontin',
#   'Halcion',
#   'Zaleplon',
#   'Eszopiclone',
#   'Seroquel',
#   'Unisom SleepTabs',
#   'Sominex',
#   'Doxylamine',
#   'Simply Sleep',
#   'Olanzapine',
#   'Remeron',
#   'Sonata',
#   'Doxepin',
#   'Zolpimist',
#   'Ambien CR',
#   'Tylenol PM',
#   'Zyprexa',
#   'Diphenhydramine / naproxen',
#   'Dalmane',
#   'Benadryl Allergy',
#   'Acetaminophen / diphenhydramine',
#   'Oxazepam',
#   'Somnote'],
#  'Rheumatoid Arthritis': ['Etanercept',
#   'Nabumetone',
#   'Simponi',
#   'Hydroxychloroquine',
#   'Humira',
#   'Tofacitinib',
#   'Arava',
#   'Infliximab',
#   'Naproxen',
#   'Diclofenac',
#   'Celecoxib',
#   'Acetaminophen / hydrocodone',
#   'Adalimumab',
#   'Meloxicam',
#   'Tocilizumab',
#   'Orencia',
#   'Certolizumab',
#   'Enbrel',
#   'Feldene',
#   'Golimumab',
#   'Methotrexate',
#   'Actemra',
#   'Prednisone',
#   'Leflunomide',
#   'Remicade',
#   'Mobic',
#   'Acetaminophen / tramadol',
#   'Xeljanz',
#   'Aleve',
#   'Rheumatrex Dose Pack',
#   'Methylprednisolone',
#   'Sulindac',
#   'Voltaren'],
#  'Vaginal Yeast Infection': ['Tioconazole',
#   'Fluconazole',
#   'Monistat 7-Day Combination Pack',
#   'Miconazole',
#   'Diflucan',
#   'Monistat 7',
#   'Acidophilus',
#   'Terconazole',
#   'Monistat 3-Day Combination Pack',
#   'Nystatin',
#   'Clotrimazole'],
#  'Chlamydia Infection': ['Azithromycin', 'Doxycycline'],
#  'Hirsutism': ['Eflornithine', 'Vaniqa'],
#  'Panic Disorde': ['Ativan',
#   'Clonazepam',
#   'Sertraline',
#   'Xanax',
#   'Zoloft',
#   'Klonopin',
#   'Alprazolam',
#   'Pristiq',
#   'Buspirone',
#   'Paroxetine',
#   'Paxil',
#   'Fluoxetine',
#   'Anafranil',
#   'BuSpar',
#   'Celexa',
#   'Lorazepam',
#   'Prozac',
#   'Venlafaxine',
#   'Imipramine',
#   'Clomipramine'],
#  'Migraine': ['Imitrex',
#   'Eletriptan',
#   'Zomig',
#   'Relpax',
#   'Rizatriptan',
#   'Aspirin / butalbital / caffeine',
#   'Sumatriptan',
#   'Zolmitriptan',
#   'Frovatriptan',
#   'Gabapentin',
#   'Botox',
#   'Reglan',
#   'Metoclopramide',
#   'Cambia',
#   'Acetaminophen / aspirin / caffeine',
#   'Naproxen / sumatriptan',
#   'Maxalt',
#   'Cyclobenzaprine',
#   'OnabotulinumtoxinA',
#   'Diclofenac',
#   'Sumavel DosePro',
#   'Memantine',
#   'Migranal',
#   'Dihydroergotamine',
#   'Neurontin',
#   'Cyproheptadine',
#   'Caffeine / ergotamine',
#   'Butalbital Compound',
#   'Axert',
#   'Maxalt-MLT',
#   'Flexeril',
#   'Treximet',
#   'Amerge',
#   'Naratriptan'],
#  'Azithromycin': ['Azithromycin'],
#  'Pain': ['Toradol',
#   'Morphine',
#   'Buprenorphine',
#   'Acetaminophen / hydrocodone',
#   'Camphor / menthol',
#   'Opana ER',
#   'Gabapentin',
#   'Voltaren-XR',
#   'Celecoxib',
#   'Fentanyl',
#   'Oxymorphone',
#   'Norco',
#   'Nucynta',
#   'Hysingla ER',
#   'Oxycodone',
#   'Diclofenac',
#   'Ibuprofen',
#   'Acetaminophen / oxycodone',
#   'Lortab',
#   'Tapentadol',
#   'Ketorolac',
#   'Opana',
#   'Percocet',
#   'Tramadol',
#   'Ultram ER',
#   'Cymbalta',
#   'Methadone',
#   'Butorphanol',
#   'Hydrocodone',
#   'Vicodin',
#   'Duloxetine',
#   'Voltaren',
#   'Neurontin',
#   'Pregabalin',
#   'Dilaudid',
#   'Vicodin ES',
#   'Hydromorphone',
#   'Trolamine salicylate',
#   'Roxicodone Intensol',
#   'Amitriptyline',
#   'Aspirin / caffeine',
#   'Meperidine',
#   'Pentazocine',
#   'Endocet',
#   'Naproxen',
#   'Fentora',
#   'Kadian',
#   'Voltaren Gel',
#   'Nortriptyline',
#   'Hydrocodone / ibuprofen',
#   'Motrin',
#   'Targiniq ER',
#   'Acetaminophen / propoxyphene',
#   'Lidoderm',
#   'Duragesic',
#   'Lidocaine',
#   'Fentanyl Transdermal System',
#   'Embeda',
#   'Acetaminophen / tramadol',
#   'Ketoprofen',
#   'Etodolac',
#   'Levorphanol',
#   'Ultram',
#   'Panlor SS',
#   'Methadose',
#   'Codeine',
#   'Zohydro ER',
#   'Celebrex',
#   'Roxicodone',
#   'Flector Patch',
#   'Tylenol with Codeine #3',
#   'Butrans',
#   'Nubain',
#   'Anexsia',
#   'Stadol',
#   'MS Contin',
#   'OxyContin',
#   'Acetaminophen / codeine',
#   'Aspirin / caffeine / salicylamide',
#   'Lyrica',
#   'Propoxyphene',
#   'Diflunisal',
#   'Avinza',
#   'Magnacet',
#   'Oramorph SR',
#   'Exalgo',
#   'Nalbuphine',
#   'Menthol',
#   'Diphenhydramine / naproxen',
#   'Trezix',
#   'Magnesium salicylate',
#   'Acetaminophen / caffeine / dihydrocodeine',
#   'Vicoprofen',
#   'Meperidine / promethazine'],
#  'Irritable Bowel Syndrome': ['Viberzi',
#   'Linaclotide',
#   'Lubiprostone',
#   'Venlafaxine',
#   'Amitiza',
#   'Immune globulin oral',
#   'Nortriptyline',
#   'Eluxadoline',
#   'Escitalopram',
#   'Cholestyramine',
#   'Linzess',
#   'Librax',
#   'Lactobacillus acidophilus',
#   'Dicyclomine',
#   'Chlordiazepoxide / clidinium',
#   'Metamucil',
#   'HyoMax SL',
#   'Hyoscyamine',
#   'Zelnorm',
#   'Symax Duotab',
#   'Bentyl'],
#  'Osteoarthritis': ['Mobic',
#   'Meloxicam',
#   'Orthovisc',
#   'Euflexxa',
#   'Methyl salicylate',
#   'Etodolac',
#   'Celebrex',
#   'Cataflam',
#   'Hyaluronan',
#   'Limbrel',
#   'Diclofenac',
#   'Celecoxib',
#   'Sodium hyaluronate',
#   'Capzasin-HP',
#   'Arthrotec',
#   'Voltaren Gel',
#   'Supartz',
#   'Hylan g-f 20',
#   'Triamcinolone',
#   'Synvisc-One',
#   'Synvisc',
#   'Pennsaid',
#   'Esomeprazole / naproxen',
#   'Voltaren',
#   'Bextra',
#   'Diclofenac / misoprostol',
#   'Relafen',
#   'Tylenol with Codeine #3',
#   'Cymbalta',
#   'Salonpas Pain Patch'],
#  'Constipation': ['Dulcolax',
#   "Phillips' Milk of Magnesia",
#   'Bisacodyl',
#   'Polyethylene glycol 3350',
#   'Docusate',
#   'Magnesium hydroxide',
#   'Linaclotide',
#   'Correctol',
#   'MiraLax',
#   'Magnesium citrate',
#   'Dulcolax Laxative',
#   'Fleet Enema',
#   'Senna',
#   'Linzess'],
#  'Bowel Preparation': ['MoviPrep',
#   'Prepopik',
#   'Magnesium sulfate / potassium sulfate / sodium sulfate',
#   'Suprep Bowel Prep Kit',
#   'Bisacodyl',
#   'Polyethylene glycol 3350 with electrolytes',
#   'Sodium biphosphate / sodium phosphate',
#   'Dulcolax',
#   'Citric acid / magnesium oxide / sodium picosulfate',
#   'Polyethylene glycol 3350',
#   'GoLYTELY',
#   'GaviLyte-C'],
#  'Psychosis': ['Trilafon', 'Haldol Decanoate', 'Haldol'],
#  'Muscle Spasm': ['Metaxalone',
#   'Zanaflex',
#   'Tizanidine',
#   'Valium',
#   'Norflex',
#   'Soma',
#   'Methocarbamol',
#   'Cyclobenzaprine',
#   'Carisoprodol',
#   'Flexeril',
#   'Robaxin-750',
#   'Diazepam',
#   'Robaxin',
#   'Baclofen',
#   'Skelaxin',
#   'Orphenadrine',
#   'Chlorzoxazone',
#   'Amrix'],
#  'Hepatitis C': ['Ledipasvir / sofosbuvir',
#   'Elbasvir / grazoprevir',
#   'Sovaldi',
#   'Zepatier',
#   'Epclusa',
#   'Harvoni',
#   'Sofosbuvir / velpatasvir',
#   'Ribavirin',
#   'Pegasys',
#   'Sofosbuvir',
#   'Victrelis',
#   'Simeprevir'],
#  'Overactive Bladde': ['Tamsulosin',
#   'Oxytrol',
#   'Tolterodine',
#   'Detrol LA',
#   'Myrbetriq',
#   'VESIcare',
#   'Mirabegron',
#   'Oxybutynin',
#   'Trospium',
#   'Belladonna / opium',
#   'Flomax',
#   'Botox',
#   'Solifenacin',
#   'OnabotulinumtoxinA',
#   'Gelnique'],
#  'Diabetes, Type 2': ['Dulaglutide',
#   'Liraglutide',
#   'Empagliflozin',
#   'Victoza',
#   'Exenatide',
#   'Bydureon',
#   'Trulicity',
#   'Sitagliptin',
#   'Toujeo',
#   'Empagliflozin / linagliptin',
#   'Jardiance',
#   'Dapagliflozin',
#   'Tresiba',
#   'Canagliflozin',
#   'Kombiglyze XR',
#   'Invokana',
#   'Metformin',
#   'Levemir',
#   'Insulin glargine',
#   'Afrezza',
#   'Januvia',
#   'Amaryl',
#   'Byetta',
#   'Farxiga',
#   'Janumet',
#   'Lantus Solostar',
#   'Glipizide',
#   'Insulin lispro',
#   'Onglyza',
#   'Rosiglitazone',
#   'Prandin',
#   'Albiglutide',
#   'Glimepiride',
#   'Insulin glulisine',
#   'Glimepiride / pioglitazone',
#   'GlipiZIDE XL',
#   'ActoPlus Met',
#   'Actos'],
#  'Asthma, Maintenance': ['Qvar',
#   'Alvesco',
#   'Omalizumab',
#   'Symbicort',
#   'Ciclesonide',
#   'Breo Ellipta',
#   'Xolair',
#   'Advair Diskus',
#   'Beclomethasone',
#   'Singulair',
#   'Cromolyn',
#   'Montelukast',
#   'Intal',
#   'Fluticasone / vilanterol',
#   'Intal Inhaler',
#   'Fluticasone / salmeterol'],
#  'Non-Small Cell Lung Cance': ['Opdivo',
#   'Xalkori',
#   'Erlotinib',
#   'Gilotrif',
#   'Tarceva'],
#  'Schizophrenia': ['Aripiprazole',
#   'Lurasidone',
#   'Paliperidone',
#   'Clozapine',
#   'Rexulti',
#   'Ziprasidone',
#   'Invega Sustenna',
#   'Abilify',
#   'Latuda',
#   'Risperidone',
#   'Risperdal',
#   'Iloperidone',
#   'Seroquel XR',
#   'Chlorpromazine',
#   'Olanzapine',
#   'Invega',
#   'Asenapine'],
#  'Dysuria': ['Pyridium', 'Phenazopyridine'],
#  'Smoking Cessation': ['Bupropion',
#   'Nicoderm CQ',
#   'Varenicline',
#   'Chantix',
#   'Zyban',
#   'Commit',
#   'Nicotrol Inhaler',
#   'Nicotine'],
#  'Anxiety': ['Effexor XR',
#   'Mirtazapine',
#   'Buspirone',
#   'Propranolol',
#   'Alprazolam',
#   'BuSpar',
#   'Escitalopram',
#   'Duloxetine',
#   'Lexapro',
#   'Clonazepam',
#   'Hydroxyzine',
#   'Diazepam',
#   'Gabapentin',
#   'Atarax',
#   'Cymbalta',
#   'Compazine',
#   'Lorazepam',
#   'Valium',
#   'Vilazodone',
#   'Pristiq',
#   'Klonopin',
#   'Oxazepam',
#   'Venlafaxine',
#   'Risperidone',
#   'Ativan',
#   'Desvenlafaxine',
#   'Remeron',
#   'Xanax',
#   'Paxil',
#   'Atenolol',
#   'Vistaril',
#   'Trazodone',
#   'Tenormin',
#   'Xanax XR',
#   'Tramadol',
#   'Tranxene',
#   'Wellbutrin',
#   'Paroxetine',
#   'Bupropion',
#   'Lamotrigine',
#   'Clorazepate',
#   'Librium',
#   'Oxcarbazepine',
#   'Chlordiazepoxide',
#   'Doxepin',
#   'Pexeva',
#   'Phenytoin',
#   'Wellbutrin XL'],
#  'Acne': ['Tretinoin',
#   'Ethinyl estradiol / norgestimate',
#   'Spironolactone',
#   'Adapalene / benzoyl peroxide',
#   'Isotretinoin',
#   'Aczone',
#   'Epiduo',
#   'Accutane',
#   'Solodyn',
#   'Ziana',
#   'Doxycycline',
#   'TriNessa',
#   'Tri-Sprintec',
#   'Benzoyl peroxide / clindamycin',
#   'Clindamycin / tretinoin',
#   'Differin',
#   'Minocycline',
#   'Atralin',
#   'Drospirenone / ethinyl estradiol',
#   'Sulfamethoxazole / trimethoprim',
#   'Clindamycin',
#   'Duac',
#   'Dapsone',
#   'Yaz',
#   'Doryx',
#   'Loestrin 24 Fe',
#   'Microgestin Fe 1 / 20',
#   'Adapalene',
#   'Estarylla',
#   'Magnesium hydroxide',
#   'Gildess Fe 1.5 / 30',
#   'Monodox',
#   'Aldactone',
#   'Drospirenone / ethinyl estradiol / levomefolate calcium',
#   'Junel Fe 1 / 20',
#   'Tazarotene',
#   'Ethinyl estradiol / norethindrone',
#   'Benzoyl peroxide / erythromycin',
#   'Finacea',
#   'Claravis',
#   'Acanya',
#   'Benzaclin',
#   'Yasmin',
#   'Loestrin Fe 1 / 20',
#   'Loryna',
#   'NuOx',
#   'Beyaz',
#   'Bactrim',
#   'Benzoyl peroxide',
#   'Sulfacetamide sodium / sulfur',
#   'Tri-Previfem',
#   'Gianvi',
#   'Ortho Tri-Cyclen',
#   'Tretin-X',
#   'Retin-A',
#   'Gildess Fe 1 / 20',
#   'Tazorac'],
#  'emale Infertility': ['Clomiphene', 'Clomid'],
#  'Constipation, Acute': ['Docusate / senna', 'Lactulose'],
#  'Constipation, Drug Induced': ['Amitiza',
#   'Naloxegol',
#   'Relistor',
#   'Movantik',
#   'Methylnaltrexone',
#   'Lubiprostone'],
#  'Erectile Dysfunction': ['Sildenafil',
#   'Cialis',
#   'Tadalafil',
#   'Vardenafil',
#   'Alprostadil',
#   'Viagra',
#   'Avanafil',
#   'Levitra'],
#  'Trigeminal Neuralgia': ['Oxcarbazepine',
#   'Gabapentin',
#   'Carbamazepine',
#   'Tegretol XR',
#   'Baclofen',
#   'Tegretol'],
#  'Underactive Thyroid': ['Nature-Throid',
#   'Thyroid desiccated',
#   'Levothyroxine',
#   'Liothyronine',
#   'Levothroid',
#   'Armour Thyroid',
#   'Synthroid',
#   'Levoxyl'],
#  'Chronic Pain': ['Oxycodone',
#   'Morphine',
#   'Acetaminophen / oxycodone',
#   'Methadone',
#   'Duloxetine',
#   'MS Contin',
#   'Butrans',
#   'Percocet',
#   'Fentanyl Transdermal System',
#   'Cymbalta',
#   'Buprenorphine',
#   'Fentanyl',
#   'Duragesic',
#   'Kadian',
#   'Tramadol',
#   'Dilaudid',
#   'Ultram ODT',
#   'OxyContin',
#   'Methadone Diskets',
#   'Belbuca',
#   'Subsys',
#   'Roxicodone',
#   'Embeda',
#   'Hydromorphone'],
#  'Atrophic Vaginitis': ['Estradiol',
#   'Estrace Vaginal Cream',
#   'Estring',
#   'Vagifem'],
#  'Skin and Structure Infection': ['Augmentin XR', 'Cefdinir', 'Bactroban'],
#  'Tinnitus': ['Alprazolam'],
#  'Major Depressive Disorde': ['Fluoxetine',
#   'Viibryd',
#   'Trintellix',
#   'Wellbutrin XL',
#   'Vortioxetine',
#   'Rexulti',
#   'Brexpiprazole',
#   'Fetzima',
#   'Vilazodone',
#   'Bupropion',
#   'Sertraline',
#   'Zoloft',
#   'Pristiq',
#   'Paxil',
#   'Abilify',
#   'Desvenlafaxine',
#   'Levomilnacipran',
#   'Quetiapine',
#   'Lexapro',
#   'Mirtazapine',
#   'Venlafaxine',
#   'Effexor',
#   'Aripiprazole',
#   'Prozac',
#   'Wellbutrin SR',
#   'Escitalopram',
#   'Zyprexa',
#   'Cymbalta'],
#  'Anxiety and Stress': ['Fluvoxamine',
#   'Sertraline',
#   'Citalopram',
#   'Fluoxetine',
#   'Prozac',
#   'Paroxetine',
#   'Zoloft',
#   'Amitriptyline',
#   'Celexa',
#   'Paxil',
#   'Effexor',
#   'Kava',
#   'Elavil',
#   'Venlafaxine'],
#  'Rosacea': ['Brimonidine',
#   'Doxycycline',
#   'Mirvaso',
#   'Oxymetazoline',
#   'Oracea',
#   'Finacea',
#   'Minocycline',
#   'Soolantra',
#   'Ivermectin',
#   'Clarifoam EF',
#   'Azelaic acid',
#   'Metronidazole',
#   'MetroGel',
#   'Sulfacetamide sodium / sulfur'],
#  'High Blood Pressure': ['Amlodipine / olmesartan',
#   'Lisinopril',
#   'Metoprolol',
#   'Prazosin',
#   'Toprol-XL',
#   'Losartan',
#   'Hydrochlorothiazide',
#   'Azor',
#   'Diovan',
#   'Ramipril',
#   'Valsartan',
#   'Diltiazem',
#   'Propranolol',
#   'Sectral',
#   'Hydrochlorothiazide / telmisartan',
#   'Bystolic',
#   'Bisoprolol / hydrochlorothiazide',
#   'Nebivolol',
#   'Hydrochlorothiazide / lisinopril',
#   'Amlodipine',
#   'Amlodipine / benazepril',
#   'Atenolol',
#   'Olmesartan',
#   'Irbesartan',
#   'Chlorthalidone',
#   'Benicar HCT',
#   'Doxazosin',
#   'Cozaar',
#   'Catapres-TTS',
#   'Furosemide',
#   'Benicar',
#   'Atacand',
#   'Telmisartan',
#   'Cardizem LA',
#   'Exforge',
#   'Zestril',
#   'Carvedilol',
#   'Nitro-Dur',
#   'Ziac',
#   'Clonidine',
#   'Hydrochlorothiazide / olmesartan',
#   'Avalide',
#   'Lotrel',
#   'Tenex',
#   'Hydralazine',
#   'Amlodipine / hydrochlorothiazide / olmesartan',
#   'Candesartan',
#   'Micardis',
#   'Spironolactone',
#   'Prinzide',
#   'Valturna',
#   'Hyzaar'],
#  '2</span> users found this comment helpful.': ['Loestrin 24 Fe',
#   'Jolessa',
#   'Percocet',
#   'Nexplanon',
#   'Sprintec',
#   'Levora'],
#  'Restless Legs Syndrome': ['Ropinirole',
#   'Pramipexole',
#   'Mirapex',
#   'Neupro',
#   'Gabapentin',
#   'Carbidopa / levodopa',
#   'Ultram',
#   'Clonazepam',
#   'Requip',
#   'Sinemet',
#   'Rotigotine',
#   'Tramadol',
#   'Gabapentin enacarbil'],
#  'Osteolytic Bone Metastases of Solid Tumors': ['Zoledronic acid'],
#  'Bronchitis': ['Levofloxacin',
#   'Moxifloxacin',
#   'Azithromycin',
#   'Clarithromycin',
#   'Doxycycline',
#   'Cefdinir',
#   'Levaquin',
#   'Zithromax',
#   'Ceftin',
#   'Cefprozil',
#   'Biaxin',
#   'Cefuroxime',
#   'Septra',
#   'Qvar',
#   'Factive',
#   'Amoxicillin',
#   'Guaifenesin'],
#  'Skin or Soft Tissue Infection': ['Cephalexin',
#   'Levaquin',
#   'Amoxicillin / clavulanate',
#   'Minocycline',
#   'Keflex',
#   'Doxycycline',
#   'Metronidazole',
#   'Augmentin'],
#  'Obsessive Compulsive Disorde': ['Clomipramine',
#   'Sertraline',
#   'Escitalopram',
#   'Zoloft',
#   'Prozac',
#   'Citalopram',
#   'Fluoxetine',
#   'Venlafaxine',
#   'Fluvoxamine',
#   'Mirtazapine',
#   'Luvox',
#   'Abilify',
#   'Riluzole',
#   'Zyprexa',
#   'Paroxetine',
#   'Quetiapine'],
#  'Endometriosis': ['Medroxyprogesterone',
#   'Lupron Depot',
#   'Leuprolide',
#   'Goserelin',
#   'Ethinyl estradiol / levonorgestrel',
#   'Ethinyl estradiol / norethindrone',
#   'Levlen',
#   'Ethinyl estradiol / norgestimate',
#   'Previfem',
#   'Depo-Provera',
#   'Quasense',
#   'Microgestin Fe 1 / 20',
#   'Ethinyl estradiol / norgestrel',
#   'Tri-Sprintec',
#   'Lupron',
#   'Nora-Be'],
#  'Keratoconjunctivitis Sicca': ['Restasis', 'Cyclosporine'],
#  'Breakthrough Pain': ['Fentanyl', 'Actiq', 'Duragesic'],
#  'Seizures': ['Keppra',
#   'Levetiracetam',
#   'Topamax',
#   'Lacosamide',
#   'Mysoline',
#   'Phenytoin',
#   'Oxcarbazepine',
#   'Keppra XR',
#   'Topiramate',
#   'Zonisamide'],
#  'Urea': ['Urea'],
#  'Neuropathic Pain': ['Lyrica', 'Gabapentin', 'Pregabalin'],
#  'Sedation': ['Phenergan',
#   'Promethazine',
#   'Trazodone',
#   'Hydroxyzine',
#   'Atarax'],
#  'Menstrual Disorders': ['Loestrin 21 1 / 20',
#   'Loestrin 24 Fe',
#   'Ethinyl estradiol / norethindrone',
#   'Yaz',
#   'Tranexamic acid',
#   'Gianvi',
#   'Drospirenone / ethinyl estradiol',
#   'Junel Fe 1 / 20',
#   'Loryna'],
#  'Allergic Rhinitis': ['Loratadine',
#   'Montelukast',
#   'Azelastine / fluticasone',
#   'Azelastine',
#   'Dymista',
#   'Desloratadine',
#   'Fexofenadine',
#   'Dexbrompheniramine / pseudoephedrine',
#   'Fluticasone',
#   'Loratadine / pseudoephedrine',
#   'R-Tanna',
#   'Xyzal',
#   'Methylprednisolone',
#   'Patanase',
#   'Nasacort',
#   'Chlorpheniramine',
#   'Flonase',
#   'Mometasone',
#   'Fexofenadine / pseudoephedrine',
#   'Brompheniramine',
#   'Claritin',
#   'Zyrtec',
#   'Triamcinolone',
#   'Nasacort Allergy 24HR',
#   'Singulair',
#   'Diphenhydramine',
#   'Cetirizine',
#   'Clarinex'],
#  'Anesthesia': ['Propofol',
#   'Sublimaze',
#   'Ketamine',
#   'Emla',
#   'Lidoderm',
#   'Diprivan'],
#  'Undifferentiated Connective Tissue Disease': ['Hydroxychloroquine'],
#  'Diabetes, Type 1': ['Insulin degludec'],
#  'Abnormal Uterine Bleeding': ['Provera',
#   'Medroxyprogesterone',
#   'Depo-Provera',
#   'Levonorgestrel',
#   'Mirena',
#   'Ethinyl estradiol / norgestrel',
#   'Ethinyl estradiol / levonorgestrel',
#   'Ethinyl estradiol / norgestimate',
#   'Mestranol / norethindrone',
#   'Sronyx',
#   'Norethindrone',
#   'Quasense',
#   'Alesse',
#   'Tri-Sprintec',
#   'Ethinyl estradiol / norethindrone',
#   'Ortho Tri-Cyclen',
#   'Cryselle',
#   'Tri-Previfem',
#   'Loestrin 24 Fe',
#   'Nora-Be',
#   'Estarylla',
#   'Seasonique',
#   'Aviane',
#   'Necon 1 / 35',
#   'Aygestin'],
#  'Weight Loss': ['Phentermine / topiramate',
#   'Qsymia',
#   'Adipex-P',
#   'Contrave',
#   'Phentermine',
#   'Belviq',
#   'Lorcaserin',
#   'Bupropion / naltrexone',
#   'Fastin',
#   'Megestrol',
#   'Saxenda',
#   'Liraglutide',
#   'Victoza'],
#  'Constipation, Chronic': ['Linaclotide',
#   'Linzess',
#   'Lubiprostone',
#   'Amitiza'],
#  'Breast Cancer, Metastatic': ['Ibrance', 'Anastrozole', 'Palbociclib'],
#  'Period Pain': ['Naproxen',
#   'Flurbiprofen',
#   'Mefenamic acid',
#   'Cataflam',
#   'Aleve'],
#  'Helicobacter Pylori Infection': ['Amoxicillin / clarithromycin / lansoprazole',
#   'Bismuth subcitrate potassium / metronidazole / tetracycline',
#   'Pylera',
#   'Prevpac',
#   'Aciphex'],
#  'Atrial Fibrillation': ['Metoprolol',
#   'Diltiazem',
#   'Rythmol SR',
#   'Flecainide',
#   'Xarelto',
#   'Rivaroxaban',
#   'Carvedilol',
#   'Propafenone',
#   'Digoxin',
#   'Tambocor'],
#  'Uterine Fibroids': ['Leuprolide', 'Lupron Depot'],
#  '4</span> users found this comment helpful.': ['Provera',
#   'Loestrin 24 Fe',
#   'Cymbalta',
#   'Adipex-P',
#   'Seasonique',
#   'Jolessa',
#   'Lexapro'],
#  'Kidney Infections': ['Sulfamethoxazole / trimethoprim',
#   'Levofloxacin',
#   'Cipro'],
#  'Generalized Anxiety Disorde': ['Escitalopram',
#   'Seroquel',
#   'Effexor XR',
#   'Lexapro',
#   'Venlafaxine',
#   'Citalopram',
#   'Pregabalin',
#   'Sertraline',
#   'Duloxetine',
#   'Lyrica',
#   'Quetiapine',
#   'Cymbalta',
#   'Paxil'],
#  'Asthma': ['Dulera',
#   'Montelukast',
#   'Prednisone',
#   'Dexamethasone',
#   'Breo Ellipta',
#   'Fluticasone / vilanterol',
#   'Singulair'],
#  'Postmenopausal Symptoms': ['Prempro',
#   'Climara Pro',
#   'femhrt',
#   'Estradiol',
#   'Vivelle-Dot',
#   'Enjuvia',
#   'Conjugated estrogens',
#   'Estradiol / levonorgestrel',
#   'Evamist',
#   'Junel Fe 1 / 20',
#   'Conjugated estrogens / medroxyprogesterone',
#   'Angeliq'],
#  'High Cholesterol': ['Gemfibrozil',
#   'Crestor',
#   'Repatha',
#   'Vytorin',
#   'Ezetimibe',
#   'Simvastatin',
#   'Atorvastatin',
#   'Niaspan',
#   'Welchol',
#   'Alirocumab',
#   'Zetia',
#   'Fenofibric acid',
#   'Colesevelam',
#   'Rosuvastatin',
#   'Pitavastatin',
#   'Niacin',
#   'Lipitor',
#   'Evolocumab',
#   'Livalo'],
#  'Hypogonadism, Male': ['Testosterone',
#   'AndroGel',
#   'Testim',
#   'Axiron',
#   'Fortesta',
#   'Testopel'],
#  'Hyperthyroidism': ['Methimazole'],
#  'Back Pain': ['Aleve',
#   'Relafen',
#   'Diclofenac',
#   'Norco',
#   'Acetaminophen / hydrocodone',
#   'Lorcet 10 / 650',
#   'Tramadol',
#   'Ultram',
#   'Lortab',
#   'Nabumetone',
#   'Aspirin',
#   'Naproxen',
#   'Acetaminophen / pamabrom',
#   'Vicodin',
#   'Cymbalta'],
#  'Anaplastic Oligodendroglioma': ['Temozolomide'],
#  "Sjogren's Syndrome": ['Cevimeline', 'Evoxac'],
#  'Asthma, acute': ['ProAir RespiClick',
#   'Epinephrine',
#   'Racepinephrine',
#   'Prednisolone',
#   'Albuterol',
#   'Xopenex'],
#  'Hot Flashes': ['Gabapentin',
#   'Bazedoxifene / conjugated estrogens',
#   'Venlafaxine',
#   'Duavee',
#   'Paroxetine',
#   'Brisdelle',
#   'Fluoxetine',
#   'Effexor XR'],
#  '3</span> users found this comment helpful.': ['Yaz',
#   'Skyla',
#   'ProAir HFA',
#   'Low-Ogestrel-21',
#   'Tazorac',
#   'LoSeasonique',
#   'Abilify',
#   'Augmentin',
#   'Ocella'],
#  'Herpes Simplex, Suppression': ['Valtrex', 'Valacyclovir', 'Lysine'],
#  'Bacterial Infection': ['Clindamycin',
#   'Amoxicillin / clavulanate',
#   'Bactrim DS',
#   'Metronidazole',
#   'Ceftriaxone',
#   'Azithromycin',
#   'Cephalexin',
#   'Penicillin v potassium',
#   'Flagyl',
#   'Sulfamethoxazole / trimethoprim',
#   'Penicillin VK',
#   'Vancomycin',
#   'Augmentin',
#   'Ciprofloxacin',
#   'Rocephin',
#   'Levofloxacin',
#   'Levaquin',
#   'Septra DS',
#   'Bactrim',
#   'Doxycycline'],
#  'Bursitis': ['Trolamine salicylate'],
#  'Diaper Rash': ['Boudreaux Butt Paste'],
#  'Systemic Mastocytosis': ['Gastrocrom'],
#  'Trichotillomania': ['Paroxetine', 'Fluoxetine'],
#  "Hashimoto's disease": ['Levothroid',
#   'Thyroid desiccated',
#   'Levothyroxine',
#   'Tirosint',
#   'Nature-Throid',
#   'Armour Thyroid'],
#  'Eczema': ['Pimecrolimus',
#   'Elidel',
#   'Dupixent',
#   'Mometasone',
#   'Topicort',
#   'Desonide',
#   'Halobetasol',
#   'Hydrocortisone'],
#  'Dental Abscess': ['Metronidazole', 'Amoxicillin'],
#  'Headache': ['Acetaminophen / butalbital / caffeine',
#   'Fiorinal with Codeine',
#   'Acetaminophen / dichloralphenazone / isometheptene mucate',
#   'Naproxen',
#   'Fioricet',
#   'Motrin',
#   'Esgic',
#   'Ibuprofen',
#   'Acetaminophen / diphenhydramine',
#   'Ascomp with Codeine',
#   'Acetaminophen / butalbital / caffeine / codeine',
#   'Aspirin / butalbital / caffeine / codeine',
#   'Fioricet with Codeine',
#   'Acetaminophen / caffeine / isometheptene mucate',
#   'Aspirin / butalbital / caffeine',
#   'Aleve'],
#  'Hypersomnia': ['Nuvigil', 'Modafinil', 'Caffeine'],
#  'Xerostomia': ['Saliva substitutes'],
#  'Breast Cance': ['Anastrozole',
#   'Letrozole',
#   'Femara',
#   'Exemestane',
#   'Docetaxel',
#   'Arimidex',
#   'Taxotere'],
#  'Sore Throat': ['Phenol'],
#  "Barrett's Esophagus": ['Lansoprazole', 'Protonix IV', 'Nexium'],
#  'Pain/Feve': ['Acetaminophen / aspirin / caffeine'],
#  'Diverticulitis': ['Ciprofloxacin', 'Metronidazole', 'Flagyl'],
#  'Sinusitis': ['Avelox',
#   'Augmentin',
#   'Cefdinir',
#   'Zithromax',
#   'Clarithromycin',
#   'Ciprofloxacin',
#   'Cipro',
#   'Cefuroxime',
#   'Levofloxacin',
#   'Vantin',
#   'Moxifloxacin',
#   'Levaquin',
#   'Clindamycin',
#   'Deltasone',
#   'Amoxicillin / clavulanate',
#   'Amoxil',
#   'Sulfamethoxazole / trimethoprim',
#   'Cedax',
#   'Azithromycin'],
#  'Polycystic Ovary Syndrome': ['Metformin',
#   'Falmina',
#   'Apri',
#   'Ethinyl estradiol / norethindrone',
#   'Microgestin Fe 1 / 20',
#   'Ethinyl estradiol / levonorgestrel',
#   'LoSeasonique',
#   'Sronyx',
#   'Seasonique',
#   'Yaz',
#   'Microgestin 1 / 20',
#   'Ortho-Novum 1 / 35',
#   'Loestrin 24 Fe',
#   'Drospirenone / ethinyl estradiol'],
#  'Influenza': ['Tamiflu', 'Oseltamivir'],
#  'Hypothyroidism, After Thyroid Removal': ['Liothyronine',
#   'Armour Thyroid',
#   'Levothyroxine',
#   'Synthroid'],
#  'Onychomycosis, Toenail': ['Terbinafine',
#   'Efinaconazole',
#   'Sporanox',
#   'Jublia',
#   'Fluconazole',
#   'Kerydin',
#   'Lamisil',
#   'Penlac'],
#  'Progesterone Insufficiency': ['Progesterone', 'Prometrium'],
#  '11</span> users found this comment helpful.': ['Norco',
#   'Estradiol Patch',
#   'Finacea',
#   'Xanax XR'],
#  'GERD': ['Mylanta',
#   'Dexilant',
#   'Sucralfate',
#   'Ranitidine',
#   'Dexlansoprazole',
#   'Kapidex',
#   'Prevacid',
#   'Zegerid',
#   'Pantoprazole',
#   'Esomeprazole',
#   'Nexium',
#   'Lansoprazole',
#   'Omeprazole',
#   'Metoclopramide',
#   'Rabeprazole',
#   'Aluminum hydroxide / magnesium trisilicate',
#   'Zantac',
#   'Reglan'],
#  'Nausea/Vomiting, Postoperative': ['Emend'],
#  'Herpes Simplex': ['Acyclovir', 'Docosanol', 'Abreva', 'Lysine'],
#  'Gastroparesis': ['Metoclopramide', 'Reglan'],
#  'Gout, Acute': ['Indomethacin',
#   'Colchicine',
#   'Methylprednisolone',
#   'Indocin'],
#  'Motion Sickness': ['Meclizine',
#   'Scopolamine',
#   'Dimenhydrinate',
#   'Dramamine',
#   'Bonine',
#   'Transderm-Scop'],
#  'Multiple Sclerosis': ['Gilenya',
#   'Avonex',
#   'Glatiramer',
#   'Tecfidera',
#   'Ampyra',
#   'Dalfampridine',
#   'Aubagio',
#   'Natalizumab',
#   'Tysabri',
#   'Acthar',
#   'Rebif',
#   'Copaxone',
#   'Teriflunomide',
#   'Fingolimod',
#   'Dimethyl fumarate',
#   'Interferon beta-1a'],
#  'Autism': ['Aripiprazole', 'Abilify', 'Risperidone'],
#  'Otitis Media': ['Clarithromycin',
#   'Ceftriaxone',
#   'Cefdinir',
#   'Omnicef',
#   'Amoxicillin / clavulanate'],
#  'Upper Respiratory Tract Infection': ['Bactrim DS',
#   'Amoxicillin / clavulanate',
#   'SMZ-TMP DS',
#   'Zithromax',
#   'Keflex',
#   'Amoxicillin',
#   'Azithromycin',
#   'Doxy 100',
#   'Augmentin',
#   'Erythromycin',
#   'Sulfamethoxazole / trimethoprim',
#   'Cefprozil'],
#  'Surgical Prophylaxis': ['Clindamycin'],
#  'Psoriatic Arthritis': ['Infliximab',
#   'Apremilast',
#   'Remicade',
#   'Enbrel',
#   'Humira',
#   'Adalimumab'],
#  'Erosive Esophagitis': ['Rabeprazole',
#   'Omeprazole',
#   'Esomeprazole',
#   'Nexium'],
#  'Premature Ventricular Depolarizations': ['Metoprolol'],
#  'Stomach Ulce': ['Pantoprazole',
#   'Lansoprazole',
#   'Protonix',
#   'Sucralfate',
#   'Axid AR',
#   'Omeprazole'],
#  'Doxepin': ['Doxepin'],
#  'Nausea/Vomiting': ['Zofran',
#   'Dimenhydrinate',
#   'Haldol',
#   'Ondansetron',
#   'Phosphorated carbohydrate solution',
#   'Promethazine',
#   'Prochlorperazine',
#   'Benadryl',
#   'Zofran ODT',
#   'Compazine',
#   'Reglan',
#   'Emetrol',
#   'Phenergan',
#   'Tigan',
#   'Scopolamine'],
#  'Light Anesthesia': ['Versed', 'Midazolam', 'Lorazepam'],
#  'Angina Pectoris Prophylaxis': ['Imdur'],
#  '0</span> users found this comment helpful.': ['Nortrel 1 / 35',
#   'Loestrin 24 Fe',
#   'Ortho Tri-Cyclen Lo',
#   'Mirena',
#   'Ogestrel-28',
#   'Depo-Provera',
#   'Implanon',
#   'GoLYTELY',
#   'Loestrin Fe 1 / 20'],
#  'Paranoid Disorde': ['Risperidone', 'Risperdal'],
#  'Prostatitis': ['Avelox', 'Ciprofloxacin', 'Levaquin'],
#  'Extrapyramidal Reaction': ['Benztropine', 'Trihexyphenidyl', 'Artane'],
#  'mance Anxiety': ['Propranolol'],
#  'Night Terrors': ['Clonazepam'],
#  'High Cholesterol, Familial Heterozygous': ['Alirocumab',
#   'Zetia',
#   'Rosuvastatin'],
#  'Spondyloarthritis': ['Remicade'],
#  'Clostridial Infection': ['Metronidazole', 'Vancomycin', 'Fidaxomicin'],
#  'Dermatomyositis': ['Hydroxychloroquine'],
#  'Bronchiectasis': ['ProAir RespiClick'],
#  'Nasal Congestion': ['Vicks Sinex Nasal Spray (old formulation)',
#   'Phenylephrine',
#   'Naphazoline',
#   'Oxymetazoline',
#   'Loratadine / pseudoephedrine',
#   'Afrin',
#   'Xylometazoline',
#   'Pseudoephedrine'],
#  'Benign Essential Trem': ['Propranolol', 'Primidone', 'Neurontin'],
#  'Angina': ['Ranexa'],
#  'moterol / mometasone)': ['Formoterol / mometasone'],
#  'Impetig': ['Retapamulin'],
#  'Conjunctivitis, Bacterial': ['Vigamox', 'Moxifloxacin', 'Tobramycin'],
#  'Post Traumatic Stress Disorde': ['Abilify Discmelt',
#   'Zoloft',
#   'Asenapine',
#   'Prazosin',
#   'Fluvoxamine',
#   'Quetiapine',
#   'Risperidone',
#   'Sertraline',
#   'Pristiq',
#   'Paroxetine',
#   'Amitriptyline',
#   'Paxil',
#   'Lamotrigine',
#   'Venlafaxine'],
#  'Alcohol Withdrawal': ['Baclofen', 'Librium', 'Chlordiazepoxide'],
#  'Psoriasis': ['Halobetasol',
#   'Humira',
#   'Ustekinumab',
#   'Methotrexate',
#   'Stelara',
#   'Infliximab',
#   'Adalimumab',
#   'Clocortolone',
#   'Calcitriol',
#   'Clobetasol',
#   'Clobex',
#   'Vectical',
#   'Acitretin',
#   'Calcipotriene',
#   'Ultravate',
#   'Taclonex',
#   'Desoximetasone',
#   'Tazorac',
#   'Enbrel'],
#  'Cold Sores': ['Valtrex',
#   'Valacyclovir',
#   'Acyclovir',
#   'Penciclovir',
#   'Sitavig',
#   'Zovirax Cream',
#   'Zovirax Ointment'],
#  'Hyperhidrosis': ['Drysol',
#   'Hypercare',
#   'Aluminum chloride hexahydrate',
#   'Oxybutynin'],
#  '1</span> users found this comment helpful.': ['Alavert D-12 Hour Allergy and Sinus',
#   'Depo-Provera',
#   'Aviane',
#   'Minastrin 24 Fe'],
#  'Ankylosing Spondylitis': ['Cimzia',
#   'Etanercept',
#   'Enbrel',
#   'Simponi',
#   'Secukinumab'],
#  'Hemorrhoids': ['Proctofoam', 'Pramoxine', 'Proctosol-HC'],
#  '142</span> users found this comment helpful.': ['Alli'],
#  'Schizoaffective Disorde': ['Olanzapine',
#   'Geodon',
#   'Zyprexa',
#   'Abilify',
#   'Asenapine',
#   'Ziprasidone',
#   'Paliperidone',
#   'Risperdal',
#   'Lurasidone',
#   'Invega Sustenna',
#   'Quetiapine',
#   'Seroquel',
#   'Seroquel XR',
#   'Latuda',
#   'Aripiprazole'],
#  'Not Listed / Othe': ['Clindamycin',
#   'Lorazepam',
#   'Azithromycin',
#   'Oxycodone',
#   'Phentermine',
#   'Diazepam',
#   'Alprazolam',
#   'Alfuzosin',
#   'Amphetamine / dextroamphetamine',
#   'Guaifenesin',
#   'Armodafinil',
#   'Ibuprofen',
#   'Lisinopril',
#   'Escitalopram',
#   'Tramadol',
#   'Nortriptyline',
#   'Gatifloxacin',
#   'Indomethacin'],
#  'Rhinitis': ['Flonase', 'Allerx Dose Pack DF', 'Fluticasone'],
#  'Oral Thrush': ['Nystatin'],
#  'Hyperlipoproteinemia': ['TriCor', 'Fenofibrate'],
#  'Ethinyl estradiol / norgestimate': ['Ethinyl estradiol / norgestimate'],
#  'Neutropenia Associated with Chemotherapy': ['Neulasta'],
#  'Osteoporosis': ['Ibandronate',
#   'Denosumab',
#   'Boniva',
#   'Zoledronic acid',
#   'Risedronate',
#   'Prolia',
#   'Teriparatide',
#   'Forteo',
#   'Reclast',
#   'Actonel',
#   'Premarin'],
#  'Reflex Sympathetic Dystrophy Syndrome': ['Pregabalin',
#   'Amitriptyline',
#   'Lyrica',
#   'Gabapentin',
#   'Neurontin'],
#  'Urticaria': ['Cetirizine',
#   'Omalizumab',
#   'Loratadine',
#   'Zyrtec',
#   'Xolair',
#   'Levocetirizine'],
#  'Narcolepsy': ['Sodium oxybate',
#   'Xyrem',
#   'Armodafinil',
#   'Nuvigil',
#   'Modafinil',
#   'Methylphenidate',
#   'Ritalin',
#   'Ritalin-SR',
#   'Adderall',
#   'Dexedrine',
#   'Amphetamine / dextroamphetamine',
#   'Dextroamphetamine'],
#  'Systemic Lupus Erythematosus': ['Hydroxychloroquine',
#   'Imuran',
#   'Plaquenil',
#   'Prednisone'],
#  'Ulcerative Colitis': ['Mesalamine',
#   'Humira',
#   'Remicade',
#   'Asacol',
#   'Imuran',
#   'Vedolizumab',
#   'Prednisone',
#   'Sulfazine',
#   'Budesonide',
#   'Azathioprine'],
#  'Adult Human Growth Hormone Deficiency': ['Humatrope', 'Somatropin'],
#  'Medroxyprogesterone': ['Medroxyprogesterone'],
#  'Bacterial Vaginitis': ['Metronidazole',
#   'Tindamax',
#   'MetroGel-Vaginal',
#   'Tinidazole',
#   'Vandazole',
#   'Clindesse',
#   'Clindamycin'],
#  'COPD, Maintenance': ['Spiriva',
#   'Tiotropium',
#   'ProAir HFA',
#   'Ipratropium',
#   'Advair Diskus',
#   'Combivent',
#   'Roflumilast',
#   'Olodaterol / tiotropium',
#   'Perforomist'],
#  'Anorexia': ['Cyproheptadine', 'Dronabinol'],
#  'TSH Suppression': ['Thyroid desiccated', 'Levothyroxine'],
#  'Breast Cancer, Adjuvant': ['Femara', 'Tamoxifen', 'Letrozole'],
#  'Glaucoma': ['Brimonidine / timolol'],
#  'Cough and Nasal Congestion': ['Mucinex D',
#   'Guaifenesin / phenylephrine',
#   'Guaifenesin / pseudoephedrine',
#   'Mucinex D Maximum Strength',
#   'Dextromethorphan / guaifenesin / phenylephrine',
#   'Chlorpheniramine / hydrocodone / pseudoephedrine',
#   'Zutripro',
#   'Brompheniramine / dextromethorphan / pseudoephedrine',
#   'Dextromethorphan / guaifenesin / pseudoephedrine'],
#  '8</span> users found this comment helpful.': ['Nexplanon',
#   'Latisse',
#   'Vicks Sinex Nasal Spray (old formulation)',
#   'Levora'],
#  'Inflammatory Conditions': ['Meloxicam',
#   'Methylprednisolone',
#   'Prednisone',
#   'Dexamethasone'],
#  'Urinary Incontinence': ['Detrol LA',
#   'Ditropan',
#   'OnabotulinumtoxinA',
#   'VESIcare',
#   'Myrbetriq',
#   'Gelnique',
#   'Oxybutynin',
#   'Levsin SL',
#   'Trospium',
#   'Cymbalta'],
#  'Gout': ['Febuxostat', 'Uloric', 'Allopurinol'],
#  'Bladder Infection': ['Cipro',
#   'Levofloxacin',
#   'Amoxicillin',
#   'Nitrofurantoin',
#   'Macrobid',
#   'Cefpodoxime',
#   'Ciprofloxacin',
#   'Trimethoprim'],
#  'Human Papillomavirus Prophylaxis': ['Gardasil',
#   'Human papillomavirus vaccine'],
#  'Glioblastoma Multiforme': ['Avastin'],
#  'Strep Throat': ['Amoxicillin / clavulanate', 'Ceftin', 'Cefdinir', 'Biaxin'],
#  'Acetaminophen / caffeine': ['Acetaminophen / caffeine'],
#  'Bacterial Skin Infection': ['Sulfamethoxazole / trimethoprim',
#   'Bactrim',
#   'Bactrim DS',
#   'A + D Cracked Skin Relief'],
#  'Hereditary Angioedema': ['Ruconest'],
#  'Cold Symptoms': ['Pseudoephedrine / triprolidine',
#   'Ephedrine / guaifenesin',
#   'Acetaminophen / chlorpheniramine / phenylephrine',
#   'Drixoral Cold and Allergy'],
#  'Labor Pain': ['Butorphanol'],
#  'Dry Skin': ['Ammonium lactate', 'EpiCeram', 'Emollients', 'Urea'],
#  'Diabetes Insipidus': ['Desmopressin'],
#  'Methicillin-Resistant Staphylococcus Aureus Infection': ['Zyvox'],
#  'Borderline Personality Disorde': ['Citalopram',
#   'Quetiapine',
#   'Abilify',
#   'Lamotrigine',
#   'Risperidone',
#   'Escitalopram',
#   'Clozapine',
#   'Topiramate',
#   'Divalproex sodium'],
#  'Amenorrhea': ['Provera', 'Medroxyprogesterone', 'Norethindrone'],
#  'Pneumonia': ['Levofloxacin',
#   'Biaxin XL',
#   'Avelox',
#   'Clarithromycin',
#   'Doxycycline',
#   'Moxifloxacin',
#   'Levaquin',
#   'Rocephin',
#   'Augmentin',
#   'Zyvox',
#   'Ceftriaxone',
#   'Cefdinir',
#   'Linezolid',
#   'Amoxil'],
#  'Seborrheic Dermatitis': ['Ovace Plus',
#   'Cutar',
#   'Sulfacetamide sodium',
#   'Coal tar'],
#  'Tavaborole': ['Tavaborole'],
#  'Interstitial Cystitis': ['Amitriptyline',
#   'Elmiron',
#   'Pentosan polysulfate sodium',
#   'Phenazopyridine'],
#  'Malaria Prevention': ['Malarone',
#   'Mefloquine',
#   'Atovaquone / proguanil',
#   'Daraprim'],
#  'Prevention of Dental Caries': ['Fluoride', 'Clinpro 5000'],
#  'Herbal Supplementation': ['Turmeric', 'Kava', 'Scullcap'],
#  'Acetaminophen / butalbital / caffeine / codeine': ['Acetaminophen / butalbital / caffeine / codeine'],
#  'Plaque Psoriasis': ['Secukinumab',
#   'Taclonex',
#   'Otezla',
#   'Adalimumab',
#   'Apremilast',
#   'Taltz',
#   'Betamethasone / calcipotriene',
#   'Cosentyx',
#   'Siliq',
#   'Ixekizumab'],
#  "Raynaud's Syndrome": ['Nifedipine', 'Norvasc'],
#  "Addison's Disease": ['Decadron'],
#  'Prostate Cance': ['Firmagon',
#   'Bicalutamide',
#   'Leuprolide',
#   'Casodex',
#   'Lupron',
#   'Zoladex',
#   'Xtandi'],
#  'Allergies': ['Hydroxyzine', 'Xyzal', 'Levocetirizine', 'Zymine'],
#  'Opioid-Induced Constipation': ['Relistor', 'Movantik', 'Naloxegol'],
#  'moterol)': ['Budesonide / formoterol', 'Formoterol'],
#  'Ethinyl estradiol / norethindrone': ['Ethinyl estradiol / norethindrone'],
#  '13</span> users found this comment helpful.': ['Accutane',
#   'Synvisc',
#   'Beyaz'],
#  'Conjugated estrogens': ['Conjugated estrogens'],
#  'Diarrhea': ['Lomotil', 'Atropine / diphenoxylate', 'Loperamide', 'Opium'],
#  'Seasonal Allergic Conjunctivitis': ['Olopatadine', 'Patanol'],
#  'Opioid Overdose': ['Narcan Injection'],
#  'Cyclobenzaprine': ['Cyclobenzaprine'],
#  'Spondylolisthesis': ['Gabapentin'],
#  'Shift Work Sleep Disorde': ['Nuvigil', 'Armodafinil'],
#  'Obstructive Sleep Apnea/Hypopnea Syndrome': ['Armodafinil',
#   'Modafinil',
#   'Provigil',
#   'Nuvigil'],
#  'Nausea/Vomiting of Pregnancy': ['Doxylamine / pyridoxine', 'Diclegis'],
#  'Mucositis': ['Saliva substitutes'],
#  'Ulcerative Colitis, Active': ['Lialda', 'Mesalamine'],
#  'Head Lice': ['Sklice', 'Ivermectin'],
#  'Tonsillitis/Pharyngitis': ['Cefdinir',
#   'Azithromycin',
#   'Clarithromycin',
#   'Penicillin v potassium',
#   'Phenol'],
#  'Pseudotumor Cerebri': ['Acetazolamide', 'Diamox'],
#  "Parkinson's Disease": ['Zelapar', 'Ropinirole', 'Comtan', 'Rytary'],
#  'Sciatica': ['Acetaminophen',
#   'Naproxen',
#   'Diclofenac / misoprostol',
#   'Arthrotec',
#   'Cyclobenzaprine',
#   'Voltaren',
#   'Ibuprofen',
#   'Aleve',
#   'Flexeril'],
#  'Cance': ['Chaparral'],
#  'Bacterial Endocarditis Prevention': ['Azithromycin'],
#  'Diarrhea, Chronic': ['Colesevelam', 'Welchol'],
#  'Hypertensive Emergency': ['Nifedipine', 'Clonidine'],
#  'Keratosis': ['Zyclara', 'Fluorouracil', 'Imiquimod'],
#  'Ovarian Cysts': ['Aviane',
#   'LoSeasonique',
#   'Ethinyl estradiol / norgestimate',
#   'Ethinyl estradiol / levonorgestrel',
#   'Sprintec'],
#  "Behcet's Disease": ['Infliximab', 'Adalimumab'],
#  'Chronic Idiopathic Constipation': ['Plecanatide'],
#  'lic Acid Deficiency': ['L-methylfolate'],
#  'Chronic Fatigue Syndrome': ['Nuvigil',
#   'Armodafinil',
#   'Amantadine',
#   'Lisdexamfetamine'],
#  'Basal Cell Carcinoma': ['Imiquimod'],
#  'Cataplexy': ['Sodium oxybate', 'Venlafaxine'],
#  "Crohn's Disease, Maintenance": ['Pentasa', 'Infliximab', 'Remicade'],
#  'Diabetic Peripheral Neuropathy': ['Pregabalin',
#   'Duloxetine',
#   'Lyrica',
#   'Topiramate',
#   'Cymbalta',
#   'Capsaicin'],
#  'Arrhythmia': ['Verapamil', 'Mexiletine', 'Tikosyn', 'Dofetilide'],
#  'Primary Ovarian Failure': ['Premarin', 'Estradiol'],
#  'Influenza Prophylaxis': ['Influenza virus vaccine, live, trivalent',
#   'Tamiflu'],
#  'Agitated State': ['Abilify', 'Aripiprazole'],
#  'Heart Failure': ['Coreg',
#   'Carvedilol',
#   'Isosorbide mononitrate',
#   'Imdur',
#   'Amlodipine'],
#  'atigue': ['Adderall', 'Modafinil'],
#  'Opiate Withdrawal': ['Methadone',
#   'Clonidine',
#   'Methocarbamol',
#   'Catapres-TTS',
#   'Methadose'],
#  'Endometrial Hyperplasia, Prophylaxis': ['Progesterone'],
#  'Immunosuppression': ['Methylprednisolone'],
#  'Dystonia': ['Tegretol', 'Carbamazepine', 'OnabotulinumtoxinA', 'Botox'],
#  'Alopecia': ['Minoxidil', 'Kenalog-10', 'Triamcinolone'],
#  'Vulvodynia': ['Tramadol'],
#  'Premenstrual Dysphoric Disorde': ['Fluoxetine',
#   'Citalopram',
#   'Drospirenone / ethinyl estradiol',
#   'Beyaz',
#   'Gianvi',
#   'Zoloft',
#   'Prozac',
#   'Sertraline',
#   'Escitalopram'],
#  'Alcohol Dependence': ['Naltrexone',
#   'Campral',
#   'Acamprosate',
#   'Ondansetron',
#   'Disulfiram',
#   'Antabuse'],
#  'Myasthenia Gravis': ['Mycophenolate mofetil', 'Pyridostigmine', 'Mestinon'],
#  'Social Anxiety Disorde': ['Risperidone',
#   'Zoloft',
#   'Effexor XR',
#   'Paxil',
#   'Sertraline',
#   'Venlafaxine'],
#  'Atopic Dermatitis': ['Eucrisa',
#   'Fluticasone',
#   'Triamcinolone',
#   'Protopic',
#   'Kenalog',
#   'Tacrolimus',
#   'Cloderm',
#   'Medrol Dosepak'],
#  'Schistosoma japonicum': ['Biltricide'],
#  'Sinus Symptoms': ['Ibuprofen / pseudoephedrine'],
#  'min / sitagliptin)': ['Metformin / sitagliptin'],
#  'Dermatitis': ['Clobetasol', 'Verdeso', 'Triamcinolone', 'Temovate'],
#  'Eye Redness': ['FreshKote', 'Prefrin'],
#  'Warts': ['Fluorouracil'],
#  'Menorrhagia': ['Tranexamic acid'],
#  'Seizure Prevention': ['Valium',
#   'Topamax',
#   'Lamictal',
#   'Topiramate',
#   'Lamotrigine',
#   'Topiragen'],
#  'Ophthalmic Surgery': ['Vigamox'],
#  'Skin Rash': ['Hydrocortisone', 'Prednisone'],
#  'Amphetamine / dextroamphetamine': ['Amphetamine / dextroamphetamine'],
#  'Condylomata Acuminata': ['Podofilox'],
#  'NSAID-Induced Ulcer Prophylaxis': ['Famotidine / ibuprofen'],
#  'Tinea Versicol': ['Selenium sulfide'],
#  'Omalizumab': ['Omalizumab'],
#  'Peripheral Neuropathy': ['Gabapentin'],
#  'Deep Vein Thrombosis': ['Rivaroxaban',
#   'Xarelto',
#   'Fondaparinux',
#   'Eliquis',
#   'Dabigatran',
#   'Enoxaparin'],
#  '6</span> users found this comment helpful.': ['Nor-QD'],
#  'Heart Attack': ['Clopidogrel'],
#  'Desogestrel / ethinyl estradiol': ['Desogestrel / ethinyl estradiol'],
#  'Pulmonary Embolism, Recurrent Event': ['Warfarin'],
#  'Light Sedation': ['Midazolam',
#   'Chlorpromazine',
#   'Versed',
#   'Phenergan',
#   'Librium'],
#  'Acute Lymphoblastic Leukemia': ['Gleevec'],
#  'Hyperprolactinemia': ['Cabergoline', 'Bromocriptine'],
#  'Indigestion': ['Omeprazole', "Phillips' Milk of Magnesia"],
#  'Hepatitis B': ['Tenofovir'],
#  'Dysautonomia': ['Amitriptyline', 'Pyridostigmine'],
#  'Status Epilepticus': ['Lorazepam', 'Ativan'],
#  'Postpartum Depression': ['Effexor XR', 'Zoloft', 'Fluoxetine'],
#  'Multiple Myeloma': ['Lenalidomide'],
#  'Prevention of Hypokalemia': ['Klor-Con'],
#  'Edema': ['Furosemide',
#   'Hydrochlorothiazide / spironolactone',
#   'Aldactone',
#   'Bumex',
#   'Lasix'],
#  'Urinary Retention': ['Bethanechol'],
#  'Prevention of Thromboembolism in Atrial Fibrillation': ['Eliquis',
#   'Apixaban',
#   'Pradaxa',
#   'Dabigatran',
#   'Warfarin'],
#  'Cluster Headaches': ['Sumatriptan', 'Verapamil', 'Prednisone'],
#  'Sexual Dysfunction, SSRI Induced': ['Sildenafil', 'Buspirone'],
#  'Dermatitis Herpetiformis': ['Decadron'],
#  'Temporomandibular Joint Disorde': ['Cyclobenzaprine',
#   'Diazepam',
#   'Baclofen'],
#  'Burns, External': ['Silvadene', 'Sodium hyaluronate'],
#  'Actinic Keratosis': ['Fluorouracil'],
#  'Pharyngitis': ['Prednisone'],
#  'Melanoma, Metastatic': ['Tafinlar'],
#  'Atrial Flutte': ['Tambocor', 'Cardizem'],
#  'Lyme Disease': ['Doxycycline', 'Cefuroxime'],
#  'Dry Eye Disease': ['Ocular lubricant', 'Xiidra', 'Lifitegrast', 'Lacrisert'],
#  'Allergic Reactions': ['Epinephrine', 'Dexchlorpheniramine', 'Prednisone'],
#  'Hypertriglyceridemia': ['Vascepa',
#   'Omega-3 polyunsaturated fatty acids',
#   'Omacor',
#   'Fenofibrate'],
#  'Pruritus': ['HC-Derma-Pax',
#   'Hydroxyzine',
#   'Diphenhydramine / hydrocortisone'],
#  'Carcinoid Tum': ['Sandostatin', 'Octreotide'],
#  'Muscle Pain': ['Naprelan', 'Naproxen', 'Aspirin / caffeine / orphenadrine'],
#  'Colorectal Cance': ['Oxaliplatin', 'Xeloda', 'Bevacizumab'],
#  'Vitamin/Mineral Supplementation during Pregnancy/Lactation': ['Multivitamin, prenatal',
#   'Ferrous sulfate'],
#  'Etonogestrel': ['Etonogestrel'],
#  'Nausea/Vomiting, Chemotherapy Induced': ['Zofran',
#   'Granisetron',
#   'Sancuso',
#   'Dexamethasone',
#   'Dronabinol',
#   'Emend'],
#  'Women (oxybutynin)': ['Oxybutynin'],
#  'Efavirenz / emtricitabine / tenofovir': ['Efavirenz / emtricitabine / tenofovir'],
#  'Primary Immunodeficiency Syndrome': ['Immune globulin subcutaneous'],
#  'New Daily Persistent Headache': ['Levetiracetam'],
#  'Pneumococcal Disease Prophylaxis': ['Prevnar 13'],
#  'Burning Mouth Syndrome': ['Clonazepam', 'Gabapentin'],
#  'Urinary Tract Stones': ['Tamsulosin'],
#  'Pantoprazole': ['Pantoprazole'],
#  'Pseudobulbar Affect': ['Dextromethorphan / quinidine', 'Nuedexta'],
#  '94</span> users found this comment helpful.': ['Mobic'],
#  'Eye Redness/Itching': ['Opcon-A'],
#  'Deep Vein Thrombosis, First Event': ['Warfarin'],
#  'Pulmonary Hypertension': ['Letairis', 'Tyvaso', 'Selexipag'],
#  'Malaria': ['Coartem', 'Atovaquone / proguanil'],
#  'Sarcoidosis': ['Prednisone'],
#  'Dietary Supplementation': ['Multivitamin', 'Ubiquinone', 'MCT'],
#  'Bulimia': ['Venlafaxine', 'Fluoxetine', 'Topamax'],
#  'Tendonitis': ['Mobic'],
#  'Nasal Polyps': ['Mometasone'],
#  'Hypokalemia': ['Potassium chloride'],
#  'Milnacipran': ['Milnacipran'],
#  'Anemia, Sickle Cell': ['Hydroxyurea'],
#  'Uveitis': ['Retisert', 'Difluprednate', 'Cyclopentolate'],
#  'Streptococcal Infection': ['Penicillin v potassium'],
#  'Perimenopausal Symptoms': ['Clonidine'],
#  'Asperger Syndrome': ['Risperidone'],
#  'Tinea Corporis': ['Oxistat', 'Terbinafine', 'Econazole'],
#  'Mania': ['Depakote', 'Divalproex sodium'],
#  'Renal Cell Carcinoma': ['Sunitinib', 'Pazopanib', 'Sutent'],
#  'COPD': ['Umeclidinium / vilanterol',
#   'Anoro Ellipta',
#   'Olodaterol / tiotropium',
#   'Roflumilast'],
#  'Biliary Cirrhosis': ['Urso Forte', 'Ursodiol'],
#  'Vertig': ['Meclizine', 'Bonine', 'Diphenidol'],
#  'Bupropion / naltrexone': ['Bupropion / naltrexone'],
#  'Reversal of Opioid Sedation': ['Narcan Injection'],
#  "Non-Hodgkin's Lymphoma": ['Rituximab'],
#  'High Cholesterol, Familial Homozygous': ['Crestor', 'Evolocumab'],
#  'Periodic Limb Movement Disorde': ['Clonazepam', 'Baclofen', 'Requip'],
#  'Supraventricular Tachycardia': ['Toprol-XL', 'Diltiazem', 'Adenosine'],
#  'Hypoestrogenism': ['Estrace Vaginal Cream'],
#  'Testosterone': ['Testosterone'],
#  'Juvenile Idiopathic Arthritis': ['Tocilizumab', 'Enbrel'],
#  'Swine Flu': ['Oseltamivir', 'Tamiflu'],
#  'Levonorgestrel': ['Levonorgestrel'],
#  'Giardiasis': ['Metronidazole'],
#  'Binge Eating Disorde': ['Lisdexamfetamine', 'Vyvanse'],
#  "Tourette's Syndrome": ['Topamax', 'Aripiprazole'],
#  'Trichomoniasis': ['Metronidazole', 'Tinidazole'],
#  'acial Wrinkles': ['OnabotulinumtoxinA', 'Tazarotene', 'Dermal filler'],
#  '28</span> users found this comment helpful.': ['Namenda XR'],
#  'Pulmonary Embolism': ['Rivaroxaban'],
#  'Conjunctivitis, Allergic': ['Bepotastine', 'Pemirolast', 'Alcaftadine'],
#  'Zolpidem': ['Zolpidem'],
#  'Avian Influenza': ['Tamiflu'],
#  '16</span> users found this comment helpful.': ['Metadate CD'],
#  'Hemangioma': ['Propranolol'],
#  'Nocturnal Leg Cramps': ['Quinine'],
#  'Thyroid Suppression Test': ['Levothyroxine'],
#  'Muscle Twitching': ['Baclofen'],
#  'Pupillary Dilation': ['Hydroxyamphetamine / tropicamide'],
#  'Drospirenone / ethinyl estradiol / levomefolate calcium': ['Drospirenone / ethinyl estradiol / levomefolate calcium'],
#  'Lennox-Gastaut Syndrome': ['Onfi', 'Clobazam'],
#  'Opiate Adjunct': ['Phenergan', 'Promethazine'],
#  'Postoperative Pain': ['Toradol', 'Ketorolac', 'Toradol IV / IM'],
#  'Candida Urinary Tract Infection': ['Fluconazole', 'Diflucan'],
#  'Phentermine': ['Phentermine'],
#  'Cerebral Spasticity': ['Gablofen'],
#  'Lipodystrophy': ['Egrifta'],
#  'Androgenetic Alopecia': ['Propecia', 'Finasteride'],
#  'Computed Tomography': ['Barium sulfate'],
#  'Mitral Valve Prolapse': ['Metoprolol'],
#  'Vitamin D Deficiency': ['Cholecalciferol'],
#  'Glaucoma, Open Angle': ['Tafluprost', 'Xalatan'],
#  'Endoscopy or Radiology Premedication': ['Diazepam'],
#  "Alzheimer's Disease": ['Memantine', 'Donepezil', 'Rivastigmine'],
#  'Ethinyl estradiol / levonorgestrel': ['Ethinyl estradiol / levonorgestrel'],
#  'Gouty Arthritis': ['Prednisone', 'Colchicine / probenecid'],
#  'Paroxysmal Supraventricular Tachycardia': ['Flecainide'],
#  'Vilazodone': ['Vilazodone'],
#  'Deep Vein Thrombosis, Prophylaxis': ['Xarelto'],
#  'Dapsone': ['Dapsone'],
#  'Gaucher Disease': ['Cerezyme'],
#  'Lymphocytic Colitis': ['Mesalamine'],
#  'Iloperidone': ['Iloperidone'],
#  'Pancreatic Cance': ['Erlotinib'],
#  'Cystic Fibrosis': ['Pancrelipase'],
#  'Noninfectious Colitis': ['Dicyclomine'],
#  '27</span> users found this comment helpful.': ['Nardil'],
#  'Nephrocalcinosis': ['Hydrochlorothiazide'],
#  'Quetiapine': ['Quetiapine'],
#  'Iron Deficiency Anemia': ['Venofer'],
#  'mulation) (phenylephrine)': ['Phenylephrine'],
#  'Hiccups': ['Thorazine'],
#  '75</span> users found this comment helpful.': ['Wellbutrin'],
#  'Bronchospasm Prophylaxis': ['Formoterol', 'Albuterol'],
#  'Chronic Spasticity': ['Baclofen', 'OnabotulinumtoxinA'],
#  'min / saxagliptin)': ['Metformin / saxagliptin'],
#  'Post-Cholecystectomy Diarrhea': ['Cholestyramine'],
#  'Postherpetic Neuralgia': ['Gabapentin',
#   'Gralise',
#   'Lidocaine',
#   'Gabapentin enacarbil'],
#  'Insomnia, Stimulant-Associated': ['Clonidine'],
#  'COPD, Acute': ['ProAir RespiClick', 'Albuterol'],
#  'Herpes Simplex Dendritic Keratitis': ['Zirgan'],
#  'Oophorectomy': ['Enjuvia', 'Conjugated estrogens'],
#  'Cyclic Vomiting Syndrome': ['Amitriptyline'],
#  'Chronic Lymphocytic Leukemia': ['Imbruvica', 'Rituxan'],
#  'Lyme Disease, Arthritis': ['Doxycycline'],
#  'Pseudomembranous Colitis': ['Metronidazole'],
#  'Conjunctivitis': ['Gatifloxacin'],
#  '15</span> users found this comment helpful.': ['Fiorinal with Codeine',
#   'Ultram'],
#  'Clonazepam': ['Clonazepam'],
#  'min)': ['Metformin'],
#  'Intraocular Hypertension': ['Latanoprost'],
#  'Aphthous Ulce': ['Lysine'],
#  'Ulcerative Colitis, Maintenance': ['Mesalamine', 'Asacol'],
#  'Melasma': ['Tri-Luma'],
#  'Lyme Disease, Neurologic': ['Doryx'],
#  'ge (amlodipine / valsartan)': ['Amlodipine / valsartan'],
#  'Carisoprodol': ['Carisoprodol'],
#  'Herpes Zoste': ['Valacyclovir', 'Acyclovir'],
#  'Mefenamic acid': ['Mefenamic acid'],
#  '12</span> users found this comment helpful.': ['Amitiza'],
#  'Cervical Dystonia': ['Botox', 'OnabotulinumtoxinA'],
#  'Labor Induction': ['Misoprostol'],
#  'Human Papilloma Virus': ['Imiquimod'],
#  'Chronic Pancreatitis': ['Hi-Vegi-Lip', 'Creon'],
#  'Emollients': ['Emollients'],
#  'Polycythemia Vera': ['Hydroxyurea'],
#  'Ethinyl estradiol / norelgestromin': ['Ethinyl estradiol / norelgestromin'],
#  '9</span> users found this comment helpful.': ['Kariva'],
#  'Dermatological Disorders': ['Benzoic acid / salicylic acid'],
#  'Lewy Body Dementia': ['Donepezil'],
#  'amilial Mediterranean Feve': ['Colchicine'],
#  'Neurosurgery': ['Dilantin'],
#  'Gastroenteritis': ['Zofran'],
#  'Macular Edema': ['Ranibizumab'],
#  'Tinea Pedis': ['Naftifine'],
#  '7</span> users found this comment helpful.': ['Plan B One-Step', 'Lortab'],
#  'Omeprazole / sodium bicarbonate': ['Omeprazole / sodium bicarbonate'],
#  'Diagnosis and Investigation': ['Lexiscan'],
#  '35</span> users found this comment helpful.': ['Remeron'],
#  'Gas': ['Gas-X'],
#  'Neuralgia': ['Lyrica'],
#  'Local Anesthesia': ['Mepivacaine', 'Dibucaine'],
#  '54</span> users found this comment helpful.': ['Euflexxa'],
#  'Fluticasone / salmeterol': ['Fluticasone / salmeterol'],
#  'Acute Coronary Syndrome': ['Effient', 'Ticagrelor'],
#  'Lurasidone': ['Lurasidone'],
#  'Baclofen': ['Baclofen'],
#  'Aspiration Pneumonia': ['Amoxicillin / clavulanate'],
#  'Idiopathic Thrombocytopenic Purpura': ['WinRho SDF'],
#  'Onychomycosis, Fingernail': ['Terbinafine', 'Sporanox'],
#  'Meloxicam': ['Meloxicam'],
#  'Photoaging of the Skin': ['Tretinoin'],
#  'Premature Lab': ['Makena'],
#  'Precocious Puberty': ['Lupron Depot-PED', 'Leuprolide'],
#  'Prevention of Bladder infection': ['Macrodantin', 'Nitrofurantoin'],
#  'Seasonal Affective Disorde': ['Bupropion'],
#  'Diabetic Kidney Disease': ['Ramipril'],
#  "Crohn's Disease, Acute": ['Entocort EC'],
#  'Insulin Resistance Syndrome': ['Metformin'],
#  'Lubiprostone': ['Lubiprostone'],
#  'Pudendal Neuralgia': ['Gabapentin'],
#  'Imiquimod': ['Imiquimod'],
#  "Reiter's Syndrome": ['Adalimumab'],
#  '17</span> users found this comment helpful.': ['Ortho Tri-Cyclen Lo'],
#  'Amyotrophic Lateral Sclerosis': ['Riluzole'],
#  'Body Dysmorphic Disorde': ['Ziprasidone'],
#  'Prosthetic Heart Valves, Mechanical Valves - Thrombosis Prophylaxis': ['Warfarin'],
#  'Dandruff': ['Salicylic acid / sulfur'],
#  'Vitamin B12 Deficiency': ['Cyanocobalamin'],
#  'Bone infection': ['Metronidazole'],
#  'Prosthetic Heart Valves, Tissue Valves - Thrombosis Prophylaxis': ['Warfarin'],
#  'Iritis': ['Loteprednol'],
#  'Allergic Urticaria': ['Hydroxyzine'],
#  'Methylphenidate': ['Methylphenidate'],
#  'Cardiovascular Risk Reduction': ['Ramipril'],
#  'Giant Cell Tumor of Bone': ['Denosumab']}

# %%
all_drug_conditions_dict['High Blood Pressure']

# %%
all_drug_conditions_dict['Birth Control']

# %% [markdown]
# A function that generates the features described above:

# %%
def add_data_features_to_review_features(review_features_df, source_features_df, all_drug_conditions_dict):
    # This function uses a "source_features_df", which is from the original dataframe, and uses it
    # to add features to the a dataframe of features have already been generated using one of the methods explored
    # above.
    
    # datetime additions
    
    # this if statement essentially detects if this function has been run before, and allows it to be re-run
    # multiple times for development purposes
    if source_features_df['date'].dtype   != 'datetime64[ns]':
        source_features_df['date']         = source_features_df.date.map(lambda x: datetime.strptime(x, '%d-%b-%y'))
        year_dummies                       = pd.get_dummies(source_features_df.date.dt.year, prefix = "year")
        review_features_df                 = pd.concat([review_features_df, year_dummies], axis = 1)
        
    review_features_df['rating_month']     = source_features_df.date.dt.month
    review_features_df['rating_day']       = source_features_df.date.dt.day
    review_features_df['rating_dayofweek'] = source_features_df.date.dt.day_of_week
    review_features_df['usefulcount']      = source_features_df['usefulCount']

        
    # creates a variable that indicates whether a competitor was mentioned
    for idx, data in source_features_df.iterrows():
        
        competitors                = all_drug_conditions_dict[data.condition]
        owndrug                    = data.drugName.lower()
        competitors                = [drug.lower() for drug in competitors if drug != owndrug]
        unique_competitors_named   = 0
        total_competitor_mentions  = 0
        owndrug_mentions           = 0
        
        for drug in competitors:
            unique_competitors_named = unique_competitors_named + (drug in data.review)
            
            for word in data.review:
                if drug == word:
                    total_competitor_mentions = total_competitor_mentions + 1
                    
                if owndrug == word:
                    owndrug_mentions = owndrug_mentions + 1
        

        review_features_df['unique_competitors_named']                = unique_competitors_named
        review_features_df['total_competitors']                       = len(competitors)
        review_features_df['total_competitor_mentions']               = total_competitor_mentions
        review_features_df['owndrug_mentions']                        = owndrug_mentions
        
        # returns zero if the denominator is zero
        def allow_zero_division(n, d):
            return n / d if d else 0
        
        review_features_df['prop_of_competitors_named']               = allow_zero_division(unique_competitors_named, len(competitors))
        review_features_df['owndrug_to_competitor_mention_ratio']     = allow_zero_division(owndrug_mentions, total_competitor_mentions)
        
        return review_features_df

# %% [markdown]
# The above method will be called on both the training and the validation data. This ensures that the features are generated exactly the same way on the training and validation data.

# %%
train_data = add_data_features_to_review_features(train_data, x_train, all_drug_conditions_dict)
val_data   = add_data_features_to_review_features(val_data, x_val, all_drug_conditions_dict)

# %% [markdown]
# Training dataset after feature engineering:

# %%
train_data.head()
# Out:
#                hav       thi       tak       day      work      pain  \
# uniqueID
# 57325     0.176254 -0.777215  2.496794  2.549079  1.174017  0.445719
# 220496    1.808628  1.527987 -0.708877 -0.616428 -0.517721 -0.413207
# 123604   -0.909089  1.459920 -0.708877  0.665644  0.852631  0.978298
# 175572   -0.356352 -0.073957  0.107406  1.801738  0.343838 -0.413207
# 193559   -0.909089 -0.777215 -0.708877  0.492185  0.667229  0.790034
#
#             effect      year      week       aft  ...  rating_month  \
# uniqueID                                          ...
# 57325     0.417015 -0.563651 -0.505000  0.515467  ...             5
# 220496    1.061675 -0.563651 -0.505000 -0.567918  ...             8
# 123604   -0.546106 -0.563651  2.819965  1.187223  ...             7
# 175572    1.415865 -0.563651 -0.505000  1.639043  ...             1
# 193559   -0.546106 -0.563651 -0.505000 -0.567918  ...            11
#
#           rating_day  rating_dayofweek  usefulcount  unique_competitors_named  \
# uniqueID
# 57325             21                 2           14                         2
# 220496            14                 6            1                         2
# 123604             6                 3            4                         2
# 175572             7                 2           76                         2
# 193559             5                 3           27                         2
#
#           total_competitors  total_competitor_mentions  owndrug_mentions  \
# uniqueID
# 57325                    94                          0                 0
# 220496                   94                          0                 0
# 123604                   94                          0                 0
# 175572                   94                          0                 0
# 193559                   94                          0                 0
#
#           prop_of_competitors_named  owndrug_to_competitor_mention_ratio
# uniqueID
# 57325                      0.021277                                    0
# 220496                     0.021277                                    0
# 123604                     0.021277                                    0
# 175572                     0.021277                                    0
# 193559                     0.021277                                    0
#
# [5 rows x 298 columns]

# %% [markdown]
# Training dataset after feature engineering:

# %%
val_data.head()
# Out:
#                hav       thi       tak       day      work      pain  \
# uniqueID
# 144223    1.688935 -0.812040  1.655360 -0.618780 -0.475526 -0.411061
# 63395    -0.390324 -0.186066 -0.007619  0.059728 -0.475526 -0.411061
# 6524      0.253691  0.614774 -0.694706 -0.618780 -0.475526 -0.411061
# 68694    -0.893716  0.393303 -0.694706 -0.618780 -0.475526 -0.411061
# 6508     -0.893716  0.212519 -0.694706 -0.618780  0.667805 -0.411061
#
#             effect      year      week       aft  ...  rating_month  \
# uniqueID                                          ...
# 144223   -0.513294 -0.565498 -0.498609  1.119192  ...             5
# 63395    -0.513294 -0.565498  0.476626  0.423814  ...             8
# 6524     -0.513294 -0.565498 -0.498609 -0.555363  ...            12
# 68694    -0.513294  1.297140 -0.498609 -0.555363  ...             3
# 6508     -0.513294 -0.565498  1.097601 -0.555363  ...             7
#
#           rating_day  rating_dayofweek  usefulcount  unique_competitors_named  \
# uniqueID
# 144223            28                 5            4                         0
# 63395             24                 2            3                         0
# 6524               1                 3            5                         0
# 68694             29                 2            6                         0
# 6508               2                 6           12                         0
#
#           total_competitors  total_competitor_mentions  owndrug_mentions  \
# uniqueID
# 144223                  105                          0                 0
# 63395                   105                          0                 0
# 6524                    105                          0                 0
# 68694                   105                          0                 0
# 6508                    105                          0                 0
#
#           prop_of_competitors_named  owndrug_to_competitor_mention_ratio
# uniqueID
# 144223                          0.0                                    0
# 63395                           0.0                                    0
# 6524                            0.0                                    0
# 68694                           0.0                                    0
# 6508                            0.0                                    0
#
# [5 rows x 298 columns]

# %% [markdown]
# ## Model Selection
# Here, the run_model function will be used to select the best performing model. The data generated above (TF-IDF features + engineered features) will be passed to each of the models below. These are:
# 1. Logistic regression
# 2. Random Forest
# 3. Gradient Boosting
# 4. Naive Bayes
#
# The outputs of the run_model function will be compared below to find the best model for predicting review negativity using the features generated thus far.

# %%
# Dictionaries containg ranges of parameters to search using the GridSearchCV function. 
# This will occur inside of the run_model function. The best parameters will be determined using the 'roc_auc' scoring method. 
# The model using the best parameters will be output from the run_model function. 

logit_params = {
            'random_state' : [0], 
            'penalty'      : ["l1"], 
            'solver'       : ["liblinear"],
            'max_iter'     : [1000]
                }

rf_params = {
              "max_depth"          : range(2, 8), 
              "min_samples_leaf"   : range(5, 55, 5), 
              "min_samples_split"  : range(10, 110, 5),
              "n_estimators"       : [100, 150, 200, 250, 300, 350, 400]
             }

gb_params = {
              "max_depth":range(2, 6), 
              "min_samples_leaf": range(5, 55, 5), 
              "min_samples_split": range(10, 110, 5),
              "subsample":[0.6, 0.7, 0.8], 
              "max_features": [2, 3, 4, 5, 6],
              "n_estimators": [50, 100, 150, 200], 
              "learning_rate": [0.1, 0.2, 0.3]
             }

nb_params = { 
                'alpha' : [0.1, 0.2, 0.25, 0.5, 0.6, 0.7, 0.8, 0.9] + list(range(1, 50))
            }


models_params = { 
              'LogisticRegressionCV'       : {'func'       : LogisticRegressionCV,
                                              'params'     : logit_params, 
                                              'search_type': 'grid'},

              'RandomForestClassifier'     : {'func'       : RandomForestClassifier,
                                              'params'     : rf_params, 
                                              'search_type': 'randomized'},
              
              'GradientBoostingClassifier' : {'func'       : GradientBoostingClassifier,
                                              'params'     : gb_params,
                                              'search_type': 'randomized'},
    
              'NaiveBayesClassifier'       : {'func'       : BernoulliNB,
                                              'params'     : nb_params,
                                              'search_type': 'grid'}   
              
             }

# %%
importances_models    = {}
train_metrics_models  = {}
test_metrics_models   = {}
best_params_models    = {}
fit_models_models     = {}


for method, data in models_params.items():
    print("Now on", method)
    try:
        (importances_models[method], 
         train_metrics_models[method], 
         test_metrics_models[method], 
         best_params_models[method], 
         fit_models_models[method])      = run_model(method, 
                                                    train_data,
                                                    y_train,
                                                    val_data,
                                                    y_val,
                                                    model_func = data['func'],
                                                    params_dict = data['params'],
                                                    search_type = data['search_type'])
        
        
    except Exception as e:
        print("Unable to do", method, "due to:", e)
# Out:
# Now on LogisticRegressionCV
#     Running model using specified parameters
#     Calculating Metrics
# Now on RandomForestClassifier
#     Running model using specified parameters
#     Calculating Metrics
# Now on GradientBoostingClassifier
#     Running model using specified parameters
#     Calculating Metrics
# Now on NaiveBayesClassifier
#     Running model using specified parameters
#     Calculating Metrics

# %% [markdown]
# ##### Performance
#
# ##### Train

# %%
train_metricsdf = pd.DataFrame(train_metrics_models)
train_metricsdf
# Out:
#                LogisticRegressionCV  RandomForestClassifier  \
# training_time            117.385463              134.864854
# accuracy                   0.808600                0.711400
# precision                  0.819170                0.710474
# recall                     0.936459                1.000000
# f1                         0.873896                0.830733
# auc                        0.857200                0.836143
#
#                GradientBoostingClassifier  NaiveBayesClassifier
# training_time                   28.574514              4.888002
# accuracy                         0.839000              0.769200
# precision                        0.826492              0.822132
# recall                           0.977972              0.860209
# f1                               0.895874              0.840740
# auc                              0.922116              0.815986

# %% [markdown]
# ##### Test

# %%
test_metricsdf = pd.DataFrame(test_metrics_models)
test_metricsdf
# Out:
#                LogisticRegressionCV  RandomForestClassifier  \
# training_time            117.385463              134.864854
# accuracy                   0.787800                0.690000
# precision                  0.791432                0.689579
# recall                     0.939279                0.999709
# f1                         0.859041                0.816176
# auc                        0.837650                0.781370
#
#                GradientBoostingClassifier  NaiveBayesClassifier
# training_time                   28.574514              4.888002
# accuracy                         0.768400              0.680800
# precision                        0.767322              0.895458
# recall                           0.952353              0.607205
# f1                               0.849883              0.723684
# auc                              0.820860              0.800462

# %% [markdown]
# ##### Model Selection:

# %% [markdown]
# A strong argument can be made for implementing either the logistic regression model or the gradient boosting model. These models exhibit similarly high performance in predictions, but the gradient boosting model features significantly lower training time. However, the logistic regression model's training time is not prohibitively high and the difference between the training and test performance for the gradient boosting model is much higher than the difference between the training and test logistic regression performance. This suggest that this gradient boosting fit may be overfit to the training data, and not as generalizable to new data as the logistic regression model. Therefore, the logistic regression model is identified as the best model. One additional benefit to selecting logistic regression is that, as a linear model, it is highly interpretable. This is illustrated below.

# %%
best_model = 'LogisticRegressionCV'

# %% [markdown]
# ##### Word/bigram Importances:
#
# ##### Logistic regression

# %%
# Top 10 word stems (or features) associated with positive reviews
logitimp = pd.Series(importances_models['LogisticRegressionCV'])
logitimp.head(10)
# Out:
# lov      0.347948
# best     0.273977
# amaz     0.229832
# wond     0.222606
# mirac    0.186067
# year     0.180021
# gre      0.172915
# sav      0.172692
# lif      0.167269
# far      0.142410
# dtype: float64

# %%
# Top 10 word stems (or features) associated with negative reviews
logitimp.tail(10).sort_values()
# Out:
# wors        -0.216853
# stop        -0.182479
# year_2016   -0.180877
# worst       -0.171532
# horr        -0.170621
# mad         -0.145234
# thi         -0.126005
# caus        -0.125504
# switch      -0.110144
# depress     -0.106183
# dtype: float64

# %% [markdown]
# ##### Random forest and Gradient boosting importances

# %%
gbimp = pd.DataFrame(importances_models['GradientBoostingClassifier'])
rfimp = pd.DataFrame(importances_models['RandomForestClassifier'])
gbimp = gbimp.merge(rfimp, 
                    left_index = True, 
                    right_index = True)\
                        .sort_values(by="GradientBoostingClassifier_imp",
                                     ascending = False)
gbimp.head(20)
# Out:
#              GradientBoostingClassifier_imp  RandomForestClassifier_imp
# usefulcount                        0.058262                    0.177927
# wors                               0.039345                    0.063236
# stop                               0.026973                    0.038513
# horr                               0.023987                    0.050700
# mad                                0.020598                    0.032066
# lov                                0.019261                    0.020837
# worst                              0.017735                    0.035955
# blee                               0.016131                    0.032611
# year_2017                          0.014556                    0.015234
# year_2016                          0.014556                    0.027717
# dizzy                              0.013470                    0.004728
# start                              0.012924                    0.019257
# gre                                0.012025                    0.009811
# best                               0.011455                    0.015357
# hav                                0.011269                    0.010925
# amaz                               0.010766                    0.006963
# heart                              0.010535                    0.004784
# nev                                0.010295                    0.005668
# wond                               0.010131                    0.005657
# did                                0.009993                    0.015880

# %% [markdown]
# ##### Naive Bayes Positivity Estimations by Feature

# %%
NB_optimal = fit_models_models['NaiveBayesClassifier']

# %%
important_features= pd.DataFrame(data    = np.transpose(np.e**NB_optimal.feature_log_prob_).astype("float32"),
                                 index   = train_data.columns,
                                 columns = ['negative_probability','positive_probability'])
pd.set_option("display.max_rows", None)
important_features.sort_values(by = 'positive_probability', ascending = False).head(10)
# Out:
#                                      negative_probability  \
# prop_of_competitors_named                        0.999931
# total_competitors                                0.999931
# rating_month                                     0.999931
# rating_day                                       0.999931
# unique_competitors_named                         0.999931
# usefulcount                                      0.940995
# rating_dayofweek                                 0.862185
# hav                                              0.370134
# tak                                              0.413994
# thi                                              0.467448
# day                                              0.353002
# work                                             0.236499
# year                                             0.237185
# effect                                           0.246094
# sid                                              0.220737
# aft                                              0.326960
# start                                            0.295436
# week                                             0.285156
# tim                                              0.250891
# al                                               0.275562
# feel                                             0.242667
# lik                                              0.224849
# med                                              0.174822
# just                                             0.194010
# month                                            0.243353
# ve                                               0.191269
# did                                              0.256373
# pain                                             0.220052
# help                                             0.155633
# year_2016                                        0.291324
# ev                                               0.225535
# ar                                               0.128906
# mor                                              0.152207
# doct                                             0.173451
# year_2015                                        0.178934
# becaus                                           0.172766
# pil                                              0.183046
# real                                             0.129592
# wil                                              0.143298
# year_2017                                        0.223479
# period                                           0.177563
# lif                                              0.069970
# ov                                               0.143298
# bef                                              0.137130
# weight                                           0.139186
# sint                                             0.121368
# got                                              0.186472
# took                                             0.167283
# oth                                              0.117941
# som                                              0.104235
# bad                                              0.151521
# gre                                              0.065858
# stil                                             0.138501
# expery                                           0.147410
# medicin                                          0.091214
# mon                                              0.158374
# bet                                              0.098753
# went                                             0.113144
# good                                             0.084361
# prescrib                                         0.091900
# wel                                              0.090529
# tri                                              0.069285
# dos                                              0.097382
# hour                                             0.107662
# sev                                              0.120683
# long                                             0.087788
# thing                                            0.084361
# anxy                                             0.100809
# littl                                            0.077508
# control                                          0.127536
# sleep                                            0.090529
# gain                                             0.134389
# giv                                              0.085732
# nev                                              0.156319
# try                                              0.101494
# ago                                              0.093956
# stop                                             0.185101
# fin                                              0.105606
# night                                            0.100123
# doe                                              0.077508
# felt                                             0.122738
# recommend                                        0.076823
# 10                                               0.067914
# depress                                          0.124109
# mak                                              0.097382
# lot                                              0.057634
# nee                                              0.054893
# year_2014                                        0.032278
# year_2013                                        0.041187
# ther                                             0.061061
# think                                            0.079564
# diff                                             0.060376
# chang                                            0.088473
# far                                              0.042558
# say                                              0.076138
# wer                                              0.119312
# problem                                          0.080935
# drug                                             0.094641
# cramp                                            0.116571
# mg                                               0.048725
# noth                                             0.072711
# year_2009                                        0.064487
# norm                                             0.061061
# going                                            0.099438
# lov                                              0.022684
# year_2011                                        0.076138
# mad                                              0.130277
# year_2012                                        0.052152
# high                                             0.050096
# eat                                              0.061061
# lost                                             0.050096
# yo                                               0.051467
# want                                             0.100809
# quot                                             0.048725
# know                                             0.078194
# old                                              0.050781
# hop                                              0.082305
# sex                                              0.079564
# bir                                              0.109032
# away                                             0.072026
# symptom                                          0.073396
# headach                                          0.108347
# acn                                              0.078879
# act                                              0.055578
# happy                                            0.027481
# abl                                              0.030907
# suff                                             0.047355
# mood                                             0.098753
# com                                              0.069970
# nause                                            0.085047
# low                                              0.058320
# howev                                            0.060376
# best                                             0.015145
# morn                                             0.046669
# clear                                            0.043243
# ont                                              0.035019
# caus                                             0.108347
# whil                                             0.064487
# thought                                          0.081620
# gon                                              0.043243
# light                                            0.050781
# lat                                              0.080249
# dur                                              0.062431
# alway                                            0.052837
# 20                                               0.039131
# year_2010                                        0.039131
# reliev                                           0.030222
# body                                             0.069285
# wond                                             0.019257
# thes                                             0.057634
# extrem                                           0.091900
# skin                                             0.058320
# ca                                               0.078194
# 30                                               0.031593
# sur                                              0.053522
# bit                                              0.029537
# coupl                                            0.036390
# complet                                          0.054893
# issu                                             0.050096
# pound                                            0.052837
# dai                                              0.032278
# new                                              0.042558
# switch                                           0.087103
# diagnos                                          0.029537
# amaz                                             0.013089
# right                                            0.055578
# result                                           0.028166
# way                                              0.045299
# anyth                                            0.050096
# everyth                                          0.042558
# half                                             0.043243
# second                                           0.055578
# someth                                           0.062431
# improv                                           0.045984
# gav                                              0.052837
# pregn                                            0.072711
# decid                                            0.046669
# read                                             0.046669
# definit                                          0.035704
# thank                                            0.016516
# spot                                             0.054208
# minut                                            0.028851
# hard                                             0.041187
# increas                                          0.054208
# wors                                             0.119997
# blood                                            0.055578
# tir                                              0.059005
# dry                                              0.034334
# easy                                             0.028166
# tre                                              0.032278
# sam                                              0.050781
# wor                                              0.048040
# peopl                                            0.042558
# stay                                             0.041187
# stomach                                          0.059690
# attack                                           0.039816
# look                                             0.037760
# past                                             0.035704
# los                                              0.030907
# driv                                             0.059005
# quit                                             0.030222
# twic                                             0.029537
# said                                             0.054208
# review                                           0.039816
# year_2008                                        0.001439
# pretty                                           0.025425
# anoth                                            0.059005
# 15                                               0.030907
# drink                                            0.017201
# anyon                                            0.039816
# ful                                              0.036390
# wher                                             0.041872
# loss                                             0.046669
# cam                                              0.040502
# sav                                              0.007607
# end                                              0.049411
# appetit                                          0.036390
# told                                             0.057634
# swing                                            0.067229
# horr                                             0.094641
# blee                                             0.099438
# worry                                            0.016516
# sometim                                          0.019942
# person                                           0.029537
# bed                                              0.032278
# produc                                           0.035704
# min                                              0.024740
# heavy                                            0.054208
# fac                                              0.046669
# today                                            0.035019
# lbs                                              0.030222
# terr                                             0.064487
# ins                                              0.036390
# wat                                              0.019942
# everyon                                          0.034334
# mild                                             0.020628
# liv                                              0.015831
# gen                                              0.026796
# 12                                               0.031593
# hap                                              0.033649
# slight                                           0.022684
# man                                              0.018572
# const                                            0.067229
# regul                                            0.020628
# continu                                          0.045984
# short                                            0.024054
# anym                                             0.030907
# fre                                              0.012404
# beg                                              0.039816
# migrain                                          0.037760
# energy                                           0.026796
# insert                                           0.042558
# ll                                               0.040502
# mov                                              0.030907
# mou                                              0.025425
# dr                                               0.034334
# infect                                           0.043928
# mirac                                            0.006236
# els                                              0.031593
# ear                                              0.030907
# immedy                                           0.037760
# soon                                             0.035704
# pan                                              0.027481
# fast                                             0.017201
# thos                                             0.035019
# insomn                                           0.022684
# deal                                             0.026110
# shot                                             0.042558
# sick                                             0.043928
# don                                              0.036390
# worst                                            0.076138
# press                                            0.026110
# wak                                              0.024740
# absolv                                           0.034334
# wait                                             0.043243
# dizzy                                            0.048725
# constip                                          0.022684
# irrit                                            0.036390
# hurt                                             0.032963
# aw                                               0.043928
# heart                                            0.041872
# breast                                           0.035704
# naus                                             0.037760
# tast                                             0.019942
# burn                                             0.029537
# musc                                             0.025425
# pack                                             0.035019
# leg                                              0.038446
# emot                                             0.037075
# diarrhe                                          0.032963
# smok                                             0.005551
# patch                                            0.018572
# remov                                            0.049411
# hair                                             0.031593
# ey                                               0.027481
# total_competitor_mentions                        0.000069
# owndrug_mentions                                 0.000069
# owndrug_to_competitor_mention_ratio              0.000069
#
#                                      positive_probability
# prop_of_competitors_named                        0.999972
# total_competitors                                0.999972
# rating_month                                     0.999972
# rating_day                                       0.999972
# unique_competitors_named                         0.999972
# usefulcount                                      0.966367
# rating_dayofweek                                 0.849175
# hav                                              0.437451
# tak                                              0.423331
# thi                                              0.386903
# day                                              0.377019
# work                                             0.343979
# year                                             0.334096
# effect                                           0.332119
# sid                                              0.297667
# aft                                              0.296255
# start                                            0.263216
# week                                             0.253050
# tim                                              0.247967
# al                                               0.232718
# feel                                             0.231588
# lik                                              0.208715
# med                                              0.207585
# just                                             0.207303
# month                                            0.205891
# ve                                               0.204479
# did                                              0.199678
# pain                                             0.197419
# help                                             0.186406
# year_2016                                        0.186123
# ev                                               0.178216
# ar                                               0.172004
# mor                                              0.169180
# doct                                             0.167203
# year_2015                                        0.164944
# becaus                                           0.163532
# pil                                              0.156755
# real                                             0.156755
# wil                                              0.148001
# year_2017                                        0.147436
# period                                           0.146589
# lif                                              0.145177
# ov                                               0.144612
# bef                                              0.143765
# weight                                           0.140376
# sint                                             0.139811
# got                                              0.138964
# took                                             0.138682
# oth                                              0.138399
# som                                              0.135576
# bad                                              0.128516
# gre                                              0.127669
# stil                                             0.127104
# expery                                           0.125974
# medicin                                          0.125127
# mon                                              0.124562
# bet                                              0.123998
# went                                             0.119479
# good                                             0.119197
# prescrib                                         0.118914
# wel                                              0.118914
# tri                                              0.117220
# dos                                              0.114679
# hour                                             0.112702
# sev                                              0.111008
# long                                             0.110725
# thing                                            0.107054
# anxy                                             0.106207
# littl                                            0.105925
# control                                          0.104795
# sleep                                            0.103665
# gain                                             0.103665
# giv                                              0.103383
# nev                                              0.103101
# try                                              0.101689
# ago                                              0.100277
# stop                                             0.099994
# fin                                              0.097735
# night                                            0.096606
# doe                                              0.095476
# felt                                             0.095194
# recommend                                        0.094911
# 10                                               0.093782
# depress                                          0.092087
# mak                                              0.090393
# lot                                              0.088981
# nee                                              0.088416
# year_2014                                        0.088134
# year_2013                                        0.088134
# ther                                             0.087852
# think                                            0.087852
# diff                                             0.087004
# chang                                            0.086440
# far                                              0.086157
# say                                              0.084745
# wer                                              0.084463
# problem                                          0.083333
# drug                                             0.082204
# cramp                                            0.082204
# mg                                               0.079945
# noth                                             0.079380
# year_2009                                        0.078815
# norm                                             0.078815
# going                                            0.078533
# lov                                              0.077121
# year_2011                                        0.077121
# mad                                              0.075144
# year_2012                                        0.074862
# high                                             0.073450
# eat                                              0.072603
# lost                                             0.071755
# yo                                               0.071473
# want                                             0.070061
# quot                                             0.069779
# know                                             0.069214
# old                                              0.068649
# hop                                              0.068367
# sex                                              0.067802
# bir                                              0.067802
# away                                             0.067519
# symptom                                          0.067519
# headach                                          0.067237
# acn                                              0.066955
# act                                              0.066955
# happy                                            0.066390
# abl                                              0.066390
# suff                                             0.065825
# mood                                             0.065543
# com                                              0.064978
# nause                                            0.064413
# low                                              0.064413
# howev                                            0.063284
# best                                             0.063001
# morn                                             0.063001
# clear                                            0.062154
# ont                                              0.061307
# caus                                             0.061025
# whil                                             0.059613
# thought                                          0.059330
# gon                                              0.059048
# light                                            0.057636
# lat                                              0.057636
# dur                                              0.057353
# alway                                            0.057071
# 20                                               0.056506
# year_2010                                        0.056224
# reliev                                           0.056224
# body                                             0.055659
# wond                                             0.055377
# thes                                             0.053965
# extrem                                           0.053682
# skin                                             0.052270
# ca                                               0.050858
# 30                                               0.050858
# sur                                              0.050858
# bit                                              0.050294
# coupl                                            0.050011
# complet                                          0.050011
# issu                                             0.049729
# pound                                            0.049729
# dai                                              0.049729
# new                                              0.049447
# switch                                           0.049164
# diagnos                                          0.048882
# amaz                                             0.048882
# right                                            0.048599
# result                                           0.048035
# way                                              0.047752
# anyth                                            0.047470
# everyth                                          0.047470
# half                                             0.047187
# second                                           0.046905
# someth                                           0.046905
# improv                                           0.046905
# gav                                              0.046905
# pregn                                            0.046623
# decid                                            0.046340
# read                                             0.045775
# definit                                          0.045493
# thank                                            0.045211
# spot                                             0.044928
# minut                                            0.044928
# hard                                             0.044646
# increas                                          0.044363
# wors                                             0.044363
# blood                                            0.044081
# tir                                              0.044081
# dry                                              0.043516
# easy                                             0.042952
# tre                                              0.042669
# sam                                              0.042387
# wor                                              0.042387
# peopl                                            0.042387
# stay                                             0.041822
# stomach                                          0.040692
# attack                                           0.040410
# look                                             0.040410
# past                                             0.040410
# los                                              0.040128
# driv                                             0.039845
# quit                                             0.039845
# twic                                             0.039280
# said                                             0.038716
# review                                           0.038716
# year_2008                                        0.038433
# pretty                                           0.038433
# anoth                                            0.038433
# 15                                               0.038151
# drink                                            0.037869
# anyon                                            0.037304
# ful                                              0.037304
# wher                                             0.037021
# loss                                             0.037021
# cam                                              0.037021
# sav                                              0.036739
# end                                              0.036457
# appetit                                          0.036457
# told                                             0.036174
# swing                                            0.035609
# horr                                             0.035327
# blee                                             0.035327
# worry                                            0.035327
# sometim                                          0.035045
# person                                           0.035045
# bed                                              0.034762
# produc                                           0.034762
# min                                              0.034762
# heavy                                            0.034762
# fac                                              0.034762
# today                                            0.034762
# lbs                                              0.034762
# terr                                             0.034480
# ins                                              0.034480
# wat                                              0.033915
# everyon                                          0.033915
# mild                                             0.033915
# liv                                              0.033633
# gen                                              0.033350
# 12                                               0.032785
# hap                                              0.032503
# slight                                           0.032503
# man                                              0.032503
# const                                            0.032503
# regul                                            0.032503
# continu                                          0.032221
# short                                            0.032221
# anym                                             0.031938
# fre                                              0.031656
# beg                                              0.031656
# migrain                                          0.031374
# energy                                           0.031374
# insert                                           0.031091
# ll                                               0.030526
# mov                                              0.030526
# mou                                              0.030244
# dr                                               0.030244
# infect                                           0.030244
# mirac                                            0.030244
# els                                              0.029962
# ear                                              0.029962
# immedy                                           0.029679
# soon                                             0.029679
# pan                                              0.029397
# fast                                             0.029114
# thos                                             0.029114
# insomn                                           0.029114
# deal                                             0.028832
# shot                                             0.028267
# sick                                             0.027985
# don                                              0.027420
# worst                                            0.026855
# press                                            0.026855
# wak                                              0.026855
# absolv                                           0.026573
# wait                                             0.026008
# dizzy                                            0.025161
# constip                                          0.024596
# irrit                                            0.024314
# hurt                                             0.023749
# aw                                               0.022902
# heart                                            0.022902
# breast                                           0.022902
# naus                                             0.022619
# tast                                             0.022337
# burn                                             0.021490
# musc                                             0.021208
# pack                                             0.020925
# leg                                              0.020925
# emot                                             0.020360
# diarrhe                                          0.018948
# smok                                             0.018948
# patch                                            0.018666
# remov                                            0.018384
# hair                                             0.016972
# ey                                               0.015277
# total_competitor_mentions                        0.000028
# owndrug_mentions                                 0.000028
# owndrug_to_competitor_mention_ratio              0.000028

# %% [markdown]
# ## Putting the model into practice

# %% [markdown]
# This function generates features using the methodology developed so far and using the model selected to estimate the probability of a review being positive. This function will be used to estimate the likelihood of a new sentence being positive or negative.

# %%
def custom_classify(model, data, feature_generation_method, thrs = 0.5):
    
    if not feature_generation_method == best_features_method:
        raise("Not supported if train_data is not generated using the same feature method")
    
    text = data.review[0]

                
    def add_engineered_features(x, data):
        x = add_data_features_to_review_features(x, data, all_drug_conditions_dict)
        year = str(data.date[0].year)
        years = ['year_2008',
                 'year_2009',
                 'year_2010',
                 'year_2011',
                 'year_2012',
                 'year_2013',
                 'year_2014',
                 'year_2015',
                 'year_2016',
                 'year_2017']
        x[years] = 0
        x['year_' + year] = 1
        return x
    
    def harmonize_columns(x, data):
        for col in x.columns:
            if col not in bow_train.columns:
                del x[col]
        x = add_engineered_features(x, data)
        columns_to_make = list(set(train_data.columns).difference(set(x.columns)))
        new_cols = pd.DataFrame(data = np.zeros((1,len(columns_to_make))), columns = columns_to_make)
        x = pd.concat([x, new_cols], axis = 1)  
        x = x[train_data.columns].copy()
        return x

    
    def generate_individual_word2vec_features(text, func):
        clean_tokens = nltk.tokenize.word_tokenize(text)
        agg_embeddings = []
        
        for index in tqdm(range(len(clean_tokens))):

            # get the document by index
            document = clean_tokens[index]

            # get word embeddings for the current document in the loop
            # the if condition handles cases where the word is not in the word2vec model 
            # this would include the words that occurred less than 5 times as limited in the code earlier
            embeddings = [word2vec.wv[word] for word in document if word in word2vec.wv]

            # if none of the words have a word embedding, there will be an empty list
            # need 300 dimensions to match the regular cases, so we'll create a list of 300 missing values
            if embeddings == []:
                agg_embeddings.append([0] * 300)
            else:
                # otherwise, just get the mean componentwise across all the word embeddings and append to our list
                agg = func(embeddings, axis = 0)
                agg_embeddings.append(agg)

        agg_embeddings = [array if isinstance(array, list) else array.tolist() for array in agg_embeddings]
        agg_embeddings = pd.DataFrame(agg_embeddings)
        return agg_embeddings
    
    if feature_generation_method == 'word2vec_avg':
        func = np.mean
        x = generate_individual_word2vec_features(text, func)
        x = harmonize_columns(x, data)
        
    elif feature_generation_method == 'word2vec_sum':
        func = np.sum
        x = generate_individual_word2vec_features(text, func)
        x = harmonize_columns(x, data)
        
        
    elif feature_generation_method == 'bag_of_words':
        count_vec = CountVectorizer(ngram_range = eval(best_bow_ngram_range), stop_words = "english", lowercase = True)
        bow_features = count_vec.fit_transform([text])
        bow_features = pd.DataFrame(bow_features.toarray(), 
                                    columns = count_vec.get_feature_names_out())
        x = bow_features
        x = harmonize_columns(x, data)
    
    elif feature_generation_method == 'tf_idf':
        tf_idf = TfidfVectorizer(ngram_range = eval(best_tf_idf_ngram_range), stop_words = "english", lowercase = True)

        tf_idf_features = tf_idf.fit_transform([text])
        tf_idf_features = pd.DataFrame(tf_idf_features.toarray(), 
                                       columns = tf_idf.get_feature_names_out())
        x = tf_idf_features
        x = harmonize_columns(x, data)
        
        

    probs = best_model_func.predict_proba(x)[0]
    prediction = ['POSITIVE review' if probs[1] > thrs else 'NEGATIVE review'][0]
    print("Probability of being a positive review:", round(probs[1], 2))
    print("Given your threshold of:", thrs, ", this review is classified as a", prediction)
    
    #return x

# %%
def cbind(review,drugName,condition,date,usefulCount):
    return pd.DataFrame(data = {
              "drugName"    : drugName,
              "condition"   : condition,
              "review"      : ' '.join(review.split()),
              "date"        : date,
              "usefulCount" : usefulCount
             },
             index = [0]
            )

# %% [markdown]
# Reviews will be simulated for Topiramate, a drug that treats Migraine Prevention. They are simulated to have been written on June 5th, 2017, with a usefulness count of 5. By keeping these features the same for all reviews, this section only focuses on the model's ability to parse text.

# %%
drugName = "Topiramate"
condition = "Migraine Prevention"
date = '05-Jun-17'
usefulCount = 5

# %%
all_drug_conditions_dict[condition]
# Out:
# ['Topiramate',
#  'Amitriptyline',
#  'Topamax',
#  'OnabotulinumtoxinA',
#  'Botox',
#  'Zonisamide',
#  'Propranolol',
#  'Elavil',
#  'Vitamin B2',
#  'Clonazepam',
#  'Divalproex sodium',
#  'Nortriptyline',
#  'Bupropion',
#  'Atenolol',
#  'Nadolol']

# %% [markdown]
# ##### Defining a negative review

# %%
neg_sentence = """
            This drug is the worst. It caused me horrible side effects.
            I had to stop and switch to nadolol. Everyone should stop taking this
            bad drug!
           """

# %%
neg_sentence = clean_text(neg_sentence)
neg_sentence
# Out:
# 'thi drug is the worst . it caus me horr sid effect . i had to stop and switch to nadolol . everyon should stop tak thi bad drug !'

# %% [markdown]
# ##### Positive review

# %%
pos_sentence = """
                This drug was so great to use. It was such a miracle
                how quickly my symptoms improved! I love this.
             """

# %%
pos_sentence = clean_text(pos_sentence)
pos_sentence
# Out:
# 'thi drug was so gre to us . it was such a mirac how quick my symptom improv ! i lov thi .'

# %%
neg_example = cbind(neg_sentence,drugName,condition,date,usefulCount)
pos_example = cbind(pos_sentence,drugName,condition,date,usefulCount)

# %% [markdown]
# ##### This is the row of data that the custom_classify function will ingest for the positive review:

# %%
pos_example
# Out:
#      drugName            condition  \
# 0  Topiramate  Migraine Prevention
#
#                                               review       date  usefulCount
# 0  thi drug was so gre to us . it was such a mira...  05-Jun-17            5

# %%
best_model_func = fit_models_models[best_model]

# %% [markdown]
# ##### Classification

# %%
custom_classify(best_model_func, neg_example, best_features_method)
# Out:
# Probability of being a positive review: 0.49
# Given your threshold of: 0.5 , this review is classified as a NEGATIVE review

# %%
custom_classify(best_model_func, pos_example, best_features_method)
# Out:
# Probability of being a positive review: 0.58
# Given your threshold of: 0.5 , this review is classified as a POSITIVE review

# %% [markdown]
# ## Conclusion
#
# The best feature generation method was TF-IDF. Using all of the features generated from TF-IDF, plus additional features, it was determined that a logistic regression model is the optimal model for predicting positive reviews.

# %% [markdown]
# ## References

# %% [markdown]
# Gräßer F., Kallumadi S., Malberg H., and Zaunseder S. 2018. "Aspect-Based Sentiment Analysis of Drug Reviews Applying Cross-Domain and Cross-Data Learning". In Proceedings of the 2018 International Conference on Digital Health (DH '18). ACM, New York, NY, USA, 121-125. https://archive.ics.uci.edu/ml/datasets/Drug+Review+Dataset+%28Drugs.com%29
#
# Harris, Z. (1954). "Distributional Structure". Word. 10 (2/3): 146–62. doi:10.1080/00437956.1954.11659520.
#
# Luhn, H. P. (1957). "A Statistical Approach to Mechanized Encoding and Searching of Literary Information". IBM Journal of Research and Development. 1 (4): 309–317. doi:10.1147/rd.14.0309.
#
# Mikolov, T., Chen, K., Corrado, G., Dean, J. (2013a). "Efficient Estimation of Word Representations in Vector Space". arXiv:1301.3781
#
# Mikolov, T., Stuskever, I., Chen, K., Corrado, G., Dean, J. (2013b). "Distributed representations of words and phrases and their compositionality". Advances in Neural Information Processing Systems. arXiv:1310.4546
#
# Spärck Jones, K. (1972). "A Statistical Interpretation of Term Specificity and Its Application in Retrieval". Journal of Documentation. 28: 11–21. CiteSeerX 10.1.1.115.8343. doi:10.1108/eb026526.
